# %%
import asyncio 
import json
import random
import os
from collections import Counter

import factory
import factory.fuzzy
import factory.random
from faker import Faker
from faker_vehicle import VehicleProvider
import pandas as pd
from openai import OpenAI, AsyncOpenAI

SEED = 43
random.seed(SEED)
factory.random.reseed_random(SEED)

fake = Faker()
fake.add_provider(VehicleProvider)
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.

# %%
openai_api_key=""

# %%
os.environ["OPENAI_API_KEY"]=openai_api_key

# %% [markdown]
# ## 1. Create Random data with Factory

# %%
k = 10000

# %%
colors = ["Green", "Black", "White", "Red", "Blue"]
type_vehicle = ["Vehicle", "Machine"]

# %%
class VehicleFactory(factory.DictFactory):
    class Meta:
        exclude = "_vehicle"

    type = factory.fuzzy.FuzzyChoice(type_vehicle)
    color = factory.fuzzy.FuzzyChoice(colors)
    _vehicle = factory.LazyAttribute(
        lambda o: fake.vehicle_object()
        if o.type == "Vehicle"
        else fake.machine_object()
    )
    brand = factory.LazyAttribute(lambda o: o._vehicle["Make"])
    model = factory.LazyAttribute(lambda o: o._vehicle["Model"])
    category = factory.LazyAttribute(lambda o: o._vehicle["Category"])
    year = factory.LazyAttribute(lambda o: o._vehicle["Year"])

    price = factory.fuzzy.FuzzyInteger(1000, 10000, 100)

# %%
VehicleFactory()
# Out:
# {'type': 'Vehicle',
#  'color': 'White',
#  'brand': 'Volkswagen',
#  'model': 'Tiguan',
#  'category': 'SUV',
#  'year': 2019,
#  'price': 9900}

# %%
vehicle = [VehicleFactory() for i in range(k)]
len(vehicle)
# Out:
# 10000

# %% [markdown]
# ## 2. LLM

# %%
semaphore = asyncio.Semaphore(5)

# %%
# Define the function to generate a description and JSON facets with OpenAI Chat API
async def generate_description_and_facets(item):
    # Fill in missing fields with default values to avoid errors
    item_with_defaults = {
        "type": item.get("type", "vehicle"),
        "brand": item.get("brand", "Unknown Brand"),
        "model": item.get("model", "Unknown Model"),
        "year": item.get("year", "Unknown Year"),
        "engine_type": item.get("engine_type", "N/A"),
        "engine_size": item.get("engine_size", "Unknown Size"),
        "transmission": item.get("transmission", "N/A"),
        "drive_type": item.get("drive_type", "N/A"),
        "fuel_type": item.get("fuel_type", "N/A"),
        "color": item.get("color", "Unknown Color"),
        "interior_color": item.get("interior_color", "Standard"),
        "trim_level": item.get("trim_level", "Standard"),
        "notable_features": item.get("notable_features", ["Standard Features"]),
        "safety_features": item.get("safety_features", ["Basic Safety Features"]),
        "price": item.get("price", "N/A"),
        "category": item.get("category", "Unknown Category"),
    }

    # Define the prompt with explicit instructions for JSON output
    prompt = f"""
    You are creating entries for a **synthetic dataset of vehicles** for a **fake car e-commerce search engine** on Elasticsearch. Each vehicle entry needs a **short, engaging description** without directly mentioning the price, but instead using adjectives like "affordable," "premium," or "budget-friendly" where appropriate. Additionally, provide a **structured JSON output for standardized facet fields**.

    For any missing fields, do not leave placeholders like "N/A" or "Unknown." Instead, infer realistic and typical values based on the vehicle's type, brand, model, year, and category. Use complete and natural values for each field, ensuring no field is left blank or with placeholder text. Use the following guidelines to infer missing details:

    - **Drive Types**: Use standardized terms like "FWD" for Front Wheel Drive, "RWD" for Rear Wheel Drive, "AWD" for All Wheel Drive, and "4WD" for Four Wheel Drive, inferred based on the vehicle type and category.
    - **Fuel Types**: Choose "Gasoline," "Diesel," "Electric," or "Hybrid" based on the vehicle’s age, category, and brand.
    - **Trim Levels**: Include a realistic trim level such as "XLE," "Sport," "SE," or "Standard" that aligns with the vehicle model and brand.
    - **Engine Type and Size**: Specify a typical engine type and size (e.g., "V6 3.5L" or "I4 2.0L") that would be common for the vehicle’s brand, model, and year.
    - **Transmission**: Use terms like "Automatic" or "Manual" for vehicles. Inferred based on vehicle type and era if not provided.
    - **Safety Features**: For vehicles, include common safety features like "ABS," "Airbags," and "Lane-keeping assist." For machinery, use "Stability control" or "Reinforced structure" where applicable.
    - **Notable Features**: List standout features, such as "Leather seats," "Navigation," "Backup camera," or "Bluetooth," inferred based on typical configurations for the brand and model.

    Below are the item details. Avoid directly referencing the price in the description, but include the `price` in the structured JSON output.

    Item details:
    - Type: {item.get("type", "vehicle")}
    - Make and Model: {item.get("brand", "Unknown Brand")} {item.get("model", "Unknown Model")}
    - Year: {item.get("year", "Unknown Year")}
    - Engine Type and Size: {item.get("engine_type", "")}
    - Transmission: {item.get("transmission", "")}
    - Drive Type: {item.get("drive_type", "")}
    - Fuel Type: {item.get("fuel_type", "")}
    - Exterior Color: {item.get("color", "Unknown Color")}
    - Interior Color: {item.get("interior_color", "Standard")}
    - Trim Level: {item.get("trim_level", "Standard")}
    - Notable Features: {', '.join(item.get("notable_features", []))}
    - Safety Features: {', '.join(item.get("safety_features", []))}
    - Price: {item.get("price", "N/A")}
    - Category: {item.get("category", "Unknown Category")}

    Please respond in **JSON format only** with the following structure, using `{{JSON START}}` and `{{JSON END}}` as delimiters around the JSON:

    {{JSON START}}
    {{
        "description": "<description_text>",
        "facets": {{
            "type": "{item_with_defaults['type']}",
            "category": "{item_with_defaults['category']}",
            "brand": "{item_with_defaults['brand']}",
            "model": "{item_with_defaults['model']}",
            "year": "{item_with_defaults['year']}",
            "engine_type": "{item_with_defaults['engine_type']}",
            "engine_size": "{item_with_defaults['engine_size']}",
            "transmission": "{item_with_defaults['transmission']}",
            "drive_type": "{item_with_defaults['drive_type']}",
            "fuel_type": "{item_with_defaults['fuel_type']}",
            "exterior_color": "{item_with_defaults['color']}",
            "interior_color": "{item_with_defaults['interior_color']}",
            "trim_level": "{item_with_defaults['trim_level']}",
            "notable_features": ["{', '.join(item_with_defaults['notable_features'])}"],
            "safety_features": ["{', '.join(item_with_defaults['safety_features'])}"],
            "price": "{item_with_defaults['price']}"
        }}
    }}
    {{JSON END}}
    """
    # Execute the API call within the semaphore context
    async with semaphore:
        response = await client.chat.completions.create(
            messages=[
                {"role": "system", "content": "You are a helpful assistant."},
                {"role": "user", "content": prompt},
            ],
            model="gpt-4o-mini",
            max_tokens=300,
            temperature=0.5,
        )

    text_response=response.choices[0].message.content.strip()
    try:
        # Find JSON within delimiters
        json_start = text_response.find(r"{JSON START}") + len(r"{JSON START}")
        json_end = text_response.find(r"{JSON END}")
        json_content = text_response[json_start:json_end].strip()
        
        # Parse the JSON part
        data = json.loads(json_content)
        return data
    except (ValueError, json.JSONDecodeError) as e:
        print("Error parsing response:", e)
        return {
            "description": "Parsing error - check response format",
            "facets": item_with_defaults  # Use original item with defaults as fallback
        }

# %%
client = AsyncOpenAI(
    # This is the default and can be omitted
    api_key=os.environ.get("OPENAI_API_KEY"),
)

# %%
items =vehicle[0:5000]

# %%
processed_data = await asyncio.gather(*[generate_description_and_facets(item) for item in items])

# %%
processed_data
# Out:
# [{'description': 'Experience the thrill of driving with this 2008 Lotus Exige S, a budget-friendly sports coupe that combines lightweight design with exhilarating performance. With its striking red exterior and agile handling, this vehicle promises an unforgettable ride. Perfect for enthusiasts seeking a unique driving experience without breaking the bank.',
#   'facets': {'type': 'Vehicle',
#    'category': 'Coupe',
#    'brand': 'Lotus',
#    'model': 'Exige S',
#    'year': '2008',
#    'engine_type': 'I4',
#    'engine_size': '1.8L',
#    'transmission': 'Manual',
#    'drive_type': 'RWD',
#    'fuel_type': 'Gasoline',
#    'exterior_color': 'Red',
#    'interior_color': 'Standard',
#    'trim_level': 'Standard',
#    'notable_features': ['Leather seats', 'Navigation', 'Bluetooth'],
#    'safety_features': ['ABS', 'Airbags', 'Stability control'],
#    'price': '5700'}},
#  {'description': 'Experience the future of driving with the 2014 BMW i3, a compact hatchback that combines sustainability with style. This budget-friendly electric vehicle boasts a striking red exterior and a modern interior that welcomes you with comfort and technology. Perfect for city driving, it offers nimble handling and an eco-conscious ride, making it an excellent choice for the environmentally aware driver.',
#   'facets': {'type': 'Vehicle',
#    'category': 'Hatchback',
#    'brand': 'BMW',
#    'model': 'i3',
#    'year': '2014',
#    'engine_type': 'Electric',
#    'engine_size': 'N/A',
#    'transmission': 'Automatic',
#    'drive_type': 'RWD',
#    'fuel_type': 'Electric',
#    'exterior_color': 'Red',
#    'interior_color': 'Standard',
#    'trim_level': 'Standard',
#    'notable_features': ['Navigation', 'Backup camera', 'Bluetooth'],
#    'safety_features': ['ABS', 'Airbags', 'Lane-keeping assist'],
#    'price': '8600'}},
#  {'description': 'Discover the power and reliability of the JCB JS200NC, a budget-friendly hydraulic excavator built for efficiency and performance. This robust machine is perfect for construction and excavation tasks, offering a dependable solution for your heavy-duty needs. Its striking blue exterior not only stands out on the job site but also reflects the quality craftsmanship of JCB. Experience the ease of operation with its standard features designed to enhance productivity.',
#   'facets': {'type': 'Machine',
#    'category': 'Hydraulic Excavator',
#    'brand': 'JCB',
#    'model': 'JS200NC',
#    'year': '2001',
#    'engine_type': 'Diesel',
#    'engine_size': '4.4L',
#    'transmission': 'Automatic',
#    'drive_type': '4WD',
#    'fuel_type': 'Diesel',
#    'exterior_color': 'Blue',
#    'interior_color': 'Standard',
#    'trim_level': 'Standard',
#    'notable_features': ['Hydraulic arm',
#     'Robust chassis',
#     'Standard controls'],
#    'safety_features': ['Stability control',
#     'Reinforced structure',
#     'Emergency stop'],
#    'price': '1200'}},
#  {'description': 'Discover the Ezee-On 5537-56-13-10, a robust cultivator designed for efficiency and ease of use. This 2007 model is perfect for both hobbyists and professionals seeking a reliable machine that delivers performance without breaking the bank. With its striking blue exterior and standard interior, it combines functionality with a touch of style. Experience the benefits of modern engineering with this budget-friendly cultivator.',
#   'facets': {'type': 'Machine',
#    'category': 'Cultivator',
#    'brand': 'Ezee-On',
#    'model': '5537-56-13-10',
#    'year': '2007',
#    'engine_type': 'Diesel',
#    'engine_size': 'I4 2.2L',
#    'transmission': 'Automatic',
#    'drive_type': '4WD',
#    'fuel_type': 'Diesel',
#    'exterior_color': 'Blue',
#    'interior_color': 'Standard',
#    'trim_level': 'Standard',
#    'notable_features': ['Adjustable tines',
#     'User-friendly controls',
#     'Compact design'],
#    'safety_features': ['Stability control', 'Reinforced structure'],
#    'price': '5700'}},
#  {'description': "Discover the power and reliability of the Caterpillar 6060 AC/6060 AC FS, a robust machine designed for heavy-duty tasks. This 2018 model comes in a striking red exterior, ensuring you stand out on the job site. With its budget-friendly operation and impressive performance, this shovel is perfect for those looking to enhance their fleet without breaking the bank. Equipped with standard features and a focus on safety, it's ready to tackle your toughest projects.",
#   'facets': {'type': 'Machine',
#    'category': 'Shovel',
#    'brand': 'Caterpillar',
#    'model': '6060 AC/6060 AC FS',
#    'year': '2018',
#    'engine_type': 'Diesel',
#    'engine_size': 'V12 18.1L',
#    'transmission': 'Automatic',
#    'drive_type': '4WD',
#    'fuel_type': 'Diesel',
#    'exterior_color': 'Red',
#    'interior_color': 'Standard',
#    'trim_level': 'Standard',
#    'notable_features': ['Hydraulic controls',
#     'High-capacity bucket',
#     'Heavy-duty tracks'],
#    'safety_features': ['ABS', 'Reinforced structure', 'Stability control'],
#    'price': '3200'}},
#  {'description': 'Experience the charm of the classic Audi A4, a budget-friendly sedan that combines German engineering with a touch of elegance. This 1999 model boasts a striking green exterior and a comfortable standard interior, making it a perfect choice for both daily commutes and weekend getaways. With its reliable performance and practical features, this vehicle is designed for those who appreciate quality without breaking the bank.',
#   'facets': {'type': 'Vehicle',
#    'category': 'Sedan, Wagon',
#    'brand': 'Audi',
#    'model': 'A4',
#    'year': '1999',
#    'engine_type': 'I4',
#    'engine_size': '1.8L',
#    'transmission': 'Automatic',
#    'drive_type': 'FWD',
#    'fuel_type': 'Gasoline',
#    'exterior_color': 'Green',
#    'interior_color': 'Standard',
#    'trim_level': 'Standard',
#    'notable_features': ['Leather seats', 'Sunroof', 'Power windows'],
#    'safety_features': ['ABS', 'Airbags', 'Traction control'],
#    'price': '2500'}},
#  {'description': 'Discover the power and reliability of the John Deere 550H LGP, a robust crawler tractor designed for heavy-duty tasks. This budget-friendly machine features a durable black exterior and a standard interior, making it perfect for both professional and personal projects. With its impressive performance and dependable build, this tractor is ready to tackle any challenge you throw at it.',
#   'facets': {'type': 'Machine',
#    'category': 'Crawler Tractor',
#    'brand': 'John Deere',
#    'model': '550H LGP',
#    'year': '2019',
#    'engine_type': 'Diesel',
#    'engine_size': '4.5L',
#    'transmission': 'Automatic',
#    'drive_type': '4WD',
#    'fuel_type': 'Diesel',
#    'exterior_color': 'Black',
#    'interior_color': 'Standard',
#    'trim_level': 'Standard',
#    'notable_features': ['Hydraulic system',
#     'Adjustable tracks',
#     'Rearview camera'],
#    'safety_features': ['Stability control',
#     'Reinforced structure',
#     'Emergency stop'],
#    'price': '2200'}},
#  {'description': 'Discover the charm of the 1997 Nissan Quest, a budget-friendly minivan that offers spaciousness and reliability for families on the go. With its blue exterior and standard interior, this vehicle combines practicality with comfort, making it a perfect choice for daily errands or weekend getaways. Experience the ease of driving with its smooth handling and ample storage space, ensuring every trip is enjoyable.',
#   'facets': {'type': 'Vehicle',
#    'category': 'Van/Minivan',
#    'brand': 'Nissan',
#    'model': 'Quest',
#    'year': '1997',
#    'engine_type': 'V6',
#    'engine_size': '3.0L',
#    'transmission': 'Automatic',
#    'drive_type': 'FWD',
#    'fuel_type': 'Gasoline',
#    'exterior_color': 'Blue',
#    'interior_color': 'Standard',
#    'trim_level': 'Standard',
#    'notable_features': ['Spacious interior',
#     'Air conditioning',
#     'AM/FM radio'],
#    'safety_features': ['ABS', 'Airbags'],
#    'price': '7300'}},
#  {'description': "Experience the perfect blend of style and efficiency with this 2019 Chevrolet Sonic. This compact sedan is designed for urban adventures, offering a budget-friendly option without compromising on comfort. With its vibrant red exterior and standard interior, it's both eye-catching and practical. Enjoy features like Bluetooth connectivity and a backup camera, making every drive enjoyable and safe.",
#   'facets': {'type': 'Vehicle',
#    'category': 'Sedan, Hatchback',
#    'brand': 'Chevrolet',
#    'model': 'Sonic',
#    'year': '2019',
#    'engine_type': 'I4',
#    'engine_size': '1.4L',
#    'transmission': 'Automatic',
#    'drive_type': 'FWD',
#    'fuel_type': 'Gasoline',
#    'exterior_color': 'Red',
#    'interior_color': 'Standard',
#    'trim_level': 'Standard',
#    'notable_features': ['Bluetooth', 'Backup camera', 'Cruise control'],
#    'safety_features': ['ABS', 'Airbags', 'Stability control'],
#    'price': '8600'}},
#  {'description': 'Discover the LiuGong 612H, a robust and reliable vibratory smooth drum roller from 2008. This machine is designed for efficiency and performance, making it an excellent choice for your construction needs. With its durable blue exterior and standard interior, it offers a practical solution for any job site. The LiuGong 612H is budget-friendly, ensuring you get the job done without breaking the bank.',
#   'facets': {'type': 'Machine',
#    'category': 'Vibratory Smooth Drum Roller',
#    'brand': 'LiuGong',
#    'model': '612H',
#    'year': '2008',
#    'engine_type': 'Diesel',
#    'engine_size': '4.5L',
#    'transmission': 'Automatic',
#    'drive_type': '4WD',
#    'fuel_type': 'Diesel',
#    'exterior_color': 'Blue',
#    'interior_color': 'Standard',
#    'trim_level': 'Standard',
#    'notable_features': ['Hydraulic lift',
#     'Vibratory system',
#     "Operator's cabin"],
#    'safety_features': ['Stability control',
#     'Reinforced structure',
#     'Emergency stop'],
#    'price': '3300'}},
#  {'description': 'Experience the power and reliability of the 2019 Caterpillar D6T XL VPAT, a premium crawler tractor designed for heavy-duty tasks. Its robust construction and advanced features make it a perfect choice for both professionals and enthusiasts seeking efficiency and durability in their projects.',
#   'facets': {'type': 'Machine',
#    'category': 'Crawler Tractor',
#    'brand': 'Caterpillar',
#    'model': 'D6T XL VPAT',
#    'year': '2019',
#    'engine_type': 'Diesel',
#    'engine_size': 'C6.6 6.6L',
#    'transmission': 'Automatic',
#    'drive_type': '4WD',
#    'fuel_type': 'Diesel',
#    'exterior_color': 'Green',
#    'interior_color': 'Standard',
#    'trim_level': 'Standard',
#    'notable_features': ['Hydraulic blade',
#     'GPS guidance',
#     'Reinforced structure'],
#    'safety_features': ['Stability control',
#     'Rollover protection',
#     'Emergency stop'],
#    'price': '1600'}},
#  {'description': 'Experience a classic blend of luxury and performance with this 1992 INFINITI G sedan. Its sleek black exterior and comfortable interior make it a stylish choice for those seeking an affordable yet sophisticated ride. With its reliable engineering and smooth handling, this vehicle is perfect for daily commutes or weekend getaways.',
#   'facets': {'type': 'Vehicle',
#    'category': 'Sedan',
#    'brand': 'INFINITI',
#    'model': 'G',
#    'year': '1992',
#    'engine_type': 'V6',
#    'engine_size': '3.0L',
#    'transmission': 'Automatic',
#    'drive_type': 'RWD',
#    'fuel_type': 'Gasoline',
#    'exterior_color': 'Black',
#    'interior_color': 'Standard',
#    'trim_level': 'Standard',
#    'notable_features': ['Leather seats', 'Sunroof', 'Cruise control'],
#    'safety_features': ['ABS', 'Airbags', 'Traction control'],
#    'price': '1700'}},
#  {'description': 'Experience the thrill of open-air driving with this charming 2004 MAZDA MX-5 Miata. This budget-friendly convertible offers a spirited performance and agile handling, making it a joy to drive on winding roads. With its sleek white exterior and standard interior, this classic roadster is perfect for those seeking a fun and stylish ride.',
#   'facets': {'type': 'Vehicle',
#    'category': 'Convertible',
#    'brand': 'MAZDA',
#    'model': 'MX-5 Miata',
#    'year': '2004',
#    'engine_type': 'I4',
#    'engine_size': '1.8L',
#    'transmission': 'Manual',
#    'drive_type': 'RWD',
#    'fuel_type': 'Gasoline',
#    'exterior_color': 'White',
#    'interior_color': 'Standard',
#    'trim_level': 'Standard',
#    'notable_features': ['Leather seats', 'Bluetooth', 'Manual transmission'],
#    'safety_features': ['ABS', 'Airbags', 'Stability control'],
#    'price': '4500'}},
#  {'description': 'Experience the charm of the classic 1994 Plymouth Colt, a budget-friendly sedan that combines reliability with a touch of nostalgia. This compact vehicle is perfect for city driving, offering easy maneuverability and a comfortable ride. Its vibrant blue exterior is sure to turn heads, while the standard interior provides all the essentials for a pleasant journey.',
#   'facets': {'type': 'Vehicle',
#    'category': 'Sedan',
#    'brand': 'Plymouth',
#    'model': 'Colt',
#    'year': '1994',
#    'engine_type': 'I4',
#    'engine_size': '1.8L',
#    'transmission': 'Automatic',
#    'drive_type': 'FWD',
#    'fuel_type': 'Gasoline',
#    'exterior_color': 'Blue',
#    'interior_color': 'Standard',
#    'trim_level': 'Standard',
#    'notable_features': ['Air Conditioning', 'AM/FM Radio', 'Power Windows'],
#    'safety_features': ['ABS', 'Airbags'],
#    'price': '8900'}},
#  {'description': 'Experience the charm of a classic with the 2001 Volvo V40. This budget-friendly wagon combines practicality with a touch of Scandinavian style. With its spacious interior and solid build, it’s perfect for family outings or daily commutes. Enjoy the reliability and comfort that Volvo is known for, making every drive a pleasure.',
#   'facets': {'type': 'Vehicle',
#    'category': 'Wagon',
#    'brand': 'Volvo',
#    'model': 'V40',
#    'year': '2001',
#    'engine_type': 'I4',
#    'engine_size': '2.0L',
#    'transmission': 'Automatic',
#    'drive_type': 'FWD',
#    'fuel_type': 'Gasoline',
#    'exterior_color': 'Blue',
#    'interior_color': 'Standard',
#    'trim_level': 'Standard',
#    'notable_features': ['Leather seats', 'Sunroof', 'CD player'],
#    'safety_features': ['ABS', 'Airbags', 'Traction control'],
#    'price': '9300'}},
#  {'description': 'Discover the perfect blend of reliability and efficiency with this 2003 Nissan Sentra. This budget-friendly sedan is ideal for daily commutes and weekend getaways, featuring a comfortable interior and a smooth ride. With its vibrant green exterior, it stands out on the road while providing all the essential features you need for a hassle-free driving experience.',
#   'facets': {'type': 'Vehicle',
#    'category': 'Sedan',
#    'brand': 'Nissan',
#    'model': 'Sentra',
#    'year': '2003',
#    'engine_type': 'I4',
#    'engine_size': '2.0L',
#    'transmission': 'Automatic',
#    'drive_type': 'FWD',
#    'fuel_type': 'Gasoline',
#    'exterior_color': 'Green',
#    'interior_color': 'Standard',
#    'trim_level': 'Standard',
#    'notable_features': ['Air Conditioning', 'AM/FM Radio', 'Power Windows'],
#    'safety_features': ['ABS', 'Airbags', 'Child Safety Locks'],
#    'price': '8900'}},
#  {'description': 'Discover the rugged reliability of the Komatsu PC300LC-7, a premium hydraulic excavator built for efficiency and performance. With its robust design and powerful capabilities, this machine is perfect for heavy-duty tasks while remaining budget-friendly for your construction needs.',
#   'facets': {'type': 'Machine',
#    'category': 'Hydraulic Excavator',
#    'brand': 'Komatsu',
#    'model': 'PC300LC-7',
#    'year': '2003',
#    'engine_type': 'Diesel',
#    'engine_size': '6.0L',
#    'transmission': 'Automatic',
#    'drive_type': '4WD',
#    'fuel_type': 'Diesel',
#    'exterior_color': 'White',
#    'interior_color': 'Standard',
#    'trim_level': 'Standard',
#    'notable_features': ['Hydraulic Thumb',
#     'Bucket with Quick Coupler',
#     'Cab with AC'],
#    'safety_features': ['Stability control',
#     'Reinforced structure',
#     'Emergency stop'],
#    'price': '5200'}},
#  {'description': 'Discover the robust and reliable Kubota U35-4HGA, a budget-friendly mini excavator perfect for your construction needs. This 2005 model combines power and efficiency, making it an ideal choice for both professionals and DIY enthusiasts. With its compact design and impressive maneuverability, you can tackle any job with ease. Experience the quality and durability that Kubota is known for.',
#   'facets': {'type': 'Machine',
#    'category': 'Mini Excavator',
#    'brand': 'Kubota',
#    'model': 'U35-4HGA',
#    'year': '2005',
#    'engine_type': 'Diesel',
#    'engine_size': 'I4 1.8L',
#    'transmission': 'Automatic',
#    'drive_type': '4WD',
#    'fuel_type': 'Diesel',
#    'exterior_color': 'Black',
#    'interior_color': 'Standard',
#    'trim_level': 'Standard',
#    'notable_features': ['Hydraulic thumb',
#     'Adjustable boom',
#     'Compact design'],
#    'safety_features': ['Stability control',
#     'Reinforced structure',
#     'Emergency stop'],
#    'price': '2600'}},
#  {'description': 'Experience the charm of the 2016 Kia Soul, a budget-friendly wagon that combines practicality with a fun design. With its spacious interior and versatile cargo space, this vehicle is perfect for city driving and weekend getaways alike. Enjoy modern conveniences and a smooth ride, making every journey enjoyable.',
#   'facets': {'type': 'Vehicle',
#    'category': 'Wagon',
#    'brand': 'Kia',
#    'model': 'Soul',
#    'year': '2016',
#    'engine_type': 'I4',
#    'engine_size': '2.0L',
#    'transmission': 'Automatic',
#    'drive_type': 'FWD',
#    'fuel_type': 'Gasoline',
#    'exterior_color': 'White',
#    'interior_color': 'Standard',
#    'trim_level': 'Standard',
#    'notable_features': ['Bluetooth', 'Backup camera', 'Touchscreen display'],
#    'safety_features': ['ABS', 'Airbags', 'Stability control'],
#    'price': '1600'}},
#  {'description': 'Experience the power and versatility of the Caterpillar 297D2, a robust multi-terrain loader designed for efficiency and performance. This 2015 model boasts a premium build quality and is perfect for tackling tough jobs with ease. Its compact design allows for maneuverability in tight spaces, making it an excellent choice for both professional contractors and DIY enthusiasts alike.',
#   'facets': {'type': 'Machine',
#    'category': 'Multi Terrain Loader',
#    'brand': 'Caterpillar',
#    'model': '297D2',
#    'year': '2015',
#    'engine_type': 'Diesel',
#    'engine_size': 'C4.4 2.2L',
#    'transmission': 'Automatic',
#    'drive_type': '4WD',
#    'fuel_type': 'Diesel',
#    'exterior_color': 'White',
#    'interior_color': 'Standard',
#    'trim_level': 'Standard',
#    'notable_features': ['Hydraulic quick coupler',
#     'High-flow hydraulics',
#     'Cab with air conditioning'],
#    'safety_features': ['Stability control',
#     'Reinforced structure',
#     'Operator presence sensing system'],
#    'price': '3300'}},
#  {'description': 'Experience the rugged elegance of the 2004 Toyota Land Cruiser, a premium SUV designed for both off-road adventures and city driving. With its spacious interior and robust build, this reliable vehicle is perfect for families and explorers alike. Enjoy the comfort of standard features and the peace of mind that comes with its strong safety ratings, all wrapped in a striking blue exterior.',
#   'facets': {'type': 'Vehicle',
#    'category': 'SUV',
#    'brand': 'Toyota',
#    'model': 'Land Cruiser',
#    'year': '2004',
#    'engine_type': 'V8',
#    'engine_size': '4.7L',
#    'transmission': 'Automatic',
#    'drive_type': '4WD',
#    'fuel_type': 'Gasoline',
#    'exterior_color': 'Blue',
#    'interior_color': 'Standard',
#    'trim_level': 'Standard',
#    'notable_features': ['Leather seats',
#     'Navigation',
#     'Backup camera',
#     'Bluetooth'],
#    'safety_features': ['ABS', 'Airbags', 'Stability control'],
#    'price': '9400'}},
#  {'description': "Experience the perfect blend of style and efficiency with this 2014 Kia Forte. This budget-friendly sedan offers a comfortable ride and modern features, making it an excellent choice for daily commuting or weekend adventures. With its sleek white exterior and practical interior, you'll enjoy every journey in this compact gem.",
#   'facets': {'type': 'Vehicle',
#    'category': 'Sedan, Coupe, Hatchback',
#    'brand': 'Kia',
#    'model': 'Forte',
#    'year': '2014',
#    'engine_type': 'I4',
#    'engine_size': '2.0L',
#    'transmission': 'Automatic',
#    'drive_type': 'FWD',
#    'fuel_type': 'Gasoline',
#    'exterior_color': 'White',
#    'interior_color': 'Standard',
#    'trim_level': 'Standard',
#    'notable_features': ['Bluetooth', 'Backup camera', 'Cruise control'],
#    'safety_features': ['ABS', 'Airbags', 'Stability control'],
#    'price': '7300'}},
#  {'description': 'Experience the reliability and efficiency of the Case IH WD 1903 Series II, a budget-friendly swather designed for optimal performance in the field. This robust machine, featuring a striking red exterior, is perfect for farmers looking to enhance their productivity without breaking the bank. Its standard trim ensures you have all the essential features to get the job done smoothly.',
#   'facets': {'type': 'Machine',
#    'category': 'Swather',
#    'brand': 'Case IH',
#    'model': 'WD 1903 Series II',
#    'year': '2011',
#    'engine_type': 'Diesel',
#    'engine_size': '4.5L',
#    'transmission': 'Automatic',
#    'drive_type': '4WD',
#    'fuel_type': 'Diesel',
#    'exterior_color': 'Red',
#    'interior_color': 'Standard',
#    'trim_level': 'Standard',
#    'notable_features': ['Hydraulic lift',
#     'Adjustable cutting height',
#     'Comfortable operator seat'],
#    'safety_features': ['Stability control',
#     'Reinforced structure',
#     'Emergency stop'],
#    'price': '1500'}},
#  {'description': "Discover the robust performance of the John Deere 160GLC, a premium midi excavator designed for efficiency and reliability. This 2003 model boasts a striking red exterior and is perfect for tackling a variety of construction tasks. With its budget-friendly maintenance and durable build, it's an excellent choice for professionals looking to enhance their fleet.",
#   'facets': {'type': 'Machine',
#    'category': 'Midi Excavator',
#    'brand': 'John Deere',
#    'model': '160GLC',
#    'year': '2003',
#    'engine_type': 'Diesel',
#    'engine_size': '4.5L',
#    'transmission': 'Automatic',
#    'drive_type': '4WD',
#    'fuel_type': 'Diesel',
#    'exterior_color': 'Red',
#    'interior_color': 'Standard',
#    'trim_level': 'Standard',
#    'notable_features': ['Hydraulic thumb',
#     'Quick coupler',
#     'Auxiliary hydraulics'],
#    'safety_features': ['Stability control',
#     'Reinforced structure',
#     'Operator presence system'],
#    'price': '8700'}},
#  {'description': 'Discover the charm of the 1996 MAZDA MPV, a budget-friendly minivan that offers spacious seating and practical features for family adventures. With its classic white exterior, this vehicle is perfect for those seeking reliability and comfort without breaking the bank.',
#   'facets': {'type': 'Vehicle',
#    'category': 'Van/Minivan',
#    'brand': 'MAZDA',
#    'model': 'MPV',
#    'year': '1996',
#    'engine_type': 'V6',
#    'engine_size': '3.0L',
#    'transmission': 'Automatic',
#    'drive_type': 'FWD',
#    'fuel_type': 'Gasoline',
#    'exterior_color': 'White',
#    'interior_color': 'Standard',
#    'trim_level': 'Standard',
#    'notable_features': ['Spacious Interior',
#     'Third Row Seating',
#     'Air Conditioning'],
#    'safety_features': ['ABS', 'Airbags'],
#    'price': '2600'}},
#  {'description': "Experience the timeless elegance of the 1997 Lexus GS, a premium sedan that combines luxury with reliability. This vehicle boasts a sleek black exterior and a comfortable standard interior. With its smooth ride and refined engineering, it's an excellent choice for those seeking an affordable yet sophisticated driving experience.",
#   'facets': {'type': 'Vehicle',
#    'category': 'Sedan',
#    'brand': 'Lexus',
#    'model': 'GS',
#    'year': '1997',
#    'engine_type': 'V6',
#    'engine_size': '3.0L',
#    'transmission': 'Automatic',
#    'drive_type': 'RWD',
#    'fuel_type': 'Gasoline',
#    'exterior_color': 'Black',
#    'interior_color': 'Standard',
#    'trim_level': 'Standard',
#    'notable_features': ['Leather seats', 'Sunroof', 'Premium sound system'],
#    'safety_features': ['ABS', 'Airbags', 'Traction control'],
#    'price': '8300'}},
#  {'description': 'Discover the power and efficiency of the Caterpillar 988K, a robust wheel loader designed for heavy-duty tasks. This budget-friendly machine offers exceptional performance with its reliable engine and standard features, making it a great addition to any construction fleet. With its striking green exterior and practical interior, it combines functionality and style seamlessly.',
#   'facets': {'type': 'Machine',
#    'category': 'Wheel Loader',
#    'brand': 'Caterpillar',
#    'model': '988K',
#    'year': '2013',
#    'engine_type': 'Diesel',
#    'engine_size': 'V8 6.4L',
#    'transmission': 'Automatic',
#    'drive_type': '4WD',
#    'fuel_type': 'Diesel',
#    'exterior_color': 'Green',
#    'interior_color': 'Standard',
#    'trim_level': 'Standard',
#    'notable_features': ['Reinforced structure',
#     'Hydraulic attachments',
#     'Air conditioning'],
#    'safety_features': ['Stability control',
#     'Rearview camera',
#     'Safety interlocks'],
#    'price': '9800'}},
#  {'description': 'This 2017 Massey Ferguson 7485 4WD Tractor is a robust workhorse designed for efficiency and reliability. With its striking red exterior and standard interior, it offers a perfect blend of functionality and style. Ideal for both agricultural tasks and landscaping projects, this budget-friendly machine is equipped to handle a variety of jobs with ease.',
#   'facets': {'type': 'Machine',
#    'category': '4WD Tractor',
#    'brand': 'Massey Ferguson',
#    'model': '7485',
#    'year': '2017',
#    'engine_type': 'Diesel',
#    'engine_size': '4.4L',
#    'transmission': 'Automatic',
#    'drive_type': '4WD',
#    'fuel_type': 'Diesel',
#    'exterior_color': 'Red',
#    'interior_color': 'Standard',
#    'trim_level': 'Standard',
#    'notable_features': ['Hydraulic lift', 'Power steering', 'Rear PTO'],
#    'safety_features': ['Stability control', 'Reinforced structure'],
#    'price': '8500'}},
#  {'description': 'Discover the charm of the 1996 Dodge Ram Wagon 2500, a reliable and spacious van that offers a comfortable ride for families and adventurers alike. With its classic black exterior and standard interior, this vehicle is a budget-friendly option for those seeking practicality without compromising on style. Perfect for road trips or daily commutes, it features ample cargo space and a strong build, ensuring you can tackle any journey with confidence.',
#   'facets': {'type': 'Vehicle',
#    'category': 'Van/Minivan',
#    'brand': 'Dodge',
#    'model': 'Ram Wagon 2500',
#    'year': '1996',
#    'engine_type': 'V8',
#    'engine_size': '5.2L',
#    'transmission': 'Automatic',
#    'drive_type': 'RWD',
#    'fuel_type': 'Gasoline',
#    'exterior_color': 'Black',
#    'interior_color': 'Standard',
#    'trim_level': 'Standard',
#    'notable_features': ['Spacious Interior',
#     'Ample Cargo Space',
#     'Air Conditioning'],
#    'safety_features': ['ABS', 'Airbags'],
#    'price': '1000'}},
#  {'description': 'Experience the blend of luxury and reliability with this 2008 Acura RL. This sedan offers a comfortable ride with its spacious interior and smooth handling, making it an excellent choice for daily commutes or long drives. With its premium features and stylish green exterior, this vehicle stands out on the road while remaining budget-friendly.',
#   'facets': {'type': 'Vehicle',
#    'category': 'Sedan',
#    'brand': 'Acura',
#    'model': 'RL',
#    'year': '2008',
#    'engine_type': 'V6',
#    'engine_size': '3.5L',
#    'transmission': 'Automatic',
#    'drive_type': 'AWD',
#    'fuel_type': 'Gasoline',
#    'exterior_color': 'Green',
#    'interior_color': 'Standard',
#    'trim_level': 'Standard',
#    'notable_features': ['Leather seats', 'Navigation', 'Bluetooth', 'Sunroof'],
#    'safety_features': ['ABS',
#     'Airbags',
#     'Lane-keeping assist',
#     'Stability control'],
#    'price': '2600'}},
#  {'description': 'Discover the charm of the classic GMC Sonoma Club Cab, a budget-friendly pickup that combines utility with a touch of vintage style. This 1992 model is perfect for those seeking a reliable workhorse with a spacious cabin and ample cargo space. Its striking white exterior and standard interior make it a timeless choice for both work and play.',
#   'facets': {'type': 'Vehicle',
#    'category': 'Pickup',
#    'brand': 'GMC',
#    'model': 'Sonoma Club Cab',
#    'year': '1992',
#    'engine_type': 'V6',
#    'engine_size': '4.3L',
#    'transmission': 'Automatic',
#    'drive_type': 'RWD',
#    'fuel_type': 'Gasoline',
#    'exterior_color': 'White',
#    'interior_color': 'Standard',
#    'trim_level': 'Standard',
#    'notable_features': ['Spacious cabin',
#     'Ample cargo space',
#     'Air conditioning'],
#    'safety_features': ['ABS', 'Airbags'],
#    'price': '2500'}},
#  {'description': 'Discover the power and reliability of the Caterpillar D250D, a robust articulated dump truck designed for heavy-duty performance. This 2005 model is perfect for those seeking a dependable machine that can tackle tough terrains with ease. With its premium build quality and efficient operation, it’s an excellent choice for any construction site.',
#   'facets': {'type': 'Machine',
#    'category': 'Articulated Dump Truck',
#    'brand': 'Caterpillar',
#    'model': 'D250D',
#    'year': '2005',
#    'engine_type': 'Diesel',
#    'engine_size': '6.6L',
#    'transmission': 'Automatic',
#    'drive_type': '4WD',
#    'fuel_type': 'Diesel',
#    'exterior_color': 'White',
#    'interior_color': 'Standard',
#    'trim_level': 'Standard',
#    'notable_features': ['High load capacity',
#     'All-terrain capability',
#     'Comfortable operator station'],
#    'safety_features': ['Stability control',
#     'Reinforced structure',
#     'Emergency braking system'],
#    'price': '9900'}},
#  {'description': "Experience the power and reliability of the Kubota BX2350, a budget-friendly 4WD tractor that's perfect for your landscaping and farming needs. This 2011 model combines robust performance with ease of use, making it an ideal choice for both professionals and hobbyists. Its sleek white exterior and standard interior ensure that you work in comfort and style.",
#   'facets': {'type': 'Machine',
#    'category': '4WD Tractor',
#    'brand': 'Kubota',
#    'model': 'BX2350',
#    'year': '2011',
#    'engine_type': 'Diesel',
#    'engine_size': 'I4 1.1L',
#    'transmission': 'Automatic',
#    'drive_type': '4WD',
#    'fuel_type': 'Diesel',
#    'exterior_color': 'White',
#    'interior_color': 'Standard',
#    'trim_level': 'Standard',
#    'notable_features': ['Hydraulic lift', 'PTO', 'Compact design'],
#    'safety_features': ['Stability control', 'Reinforced structure'],
#    'price': '5900'}},
#  {'description': "Experience the perfect blend of efficiency and space with this 2018 Toyota Highlander Hybrid. This SUV is designed for families on the go, offering a spacious interior and a smooth ride. With its eco-friendly hybrid technology, it's an affordable choice for those who want to save on fuel without sacrificing comfort. Enjoy features like a backup camera and Bluetooth connectivity, making every journey enjoyable and connected.",
#   'facets': {'type': 'Vehicle',
#    'category': 'SUV',
#    'brand': 'Toyota',
#    'model': 'Highlander Hybrid',
#    'year': '2018',
#    'engine_type': 'I4',
#    'engine_size': '2.5L',
#    'transmission': 'Automatic',
#    'drive_type': 'AWD',
#    'fuel_type': 'Hybrid',
#    'exterior_color': 'Green',
#    'interior_color': 'Standard',
#    'trim_level': 'Standard',
#    'notable_features': ['Backup camera', 'Bluetooth', 'Navigation'],
#    'safety_features': ['ABS', 'Airbags', 'Lane-keeping assist'],
#    'price': '2100'}},
#  {'description': 'Experience the perfect blend of comfort and versatility with this 2018 GMC Acadia. This SUV offers a spacious interior, making it ideal for family adventures or daily commutes. With its striking red exterior and budget-friendly appeal, it’s a fantastic choice for anyone seeking a reliable vehicle that doesn’t compromise on style.',
#   'facets': {'type': 'Vehicle',
#    'category': 'SUV',
#    'brand': 'GMC',
#    'model': 'Acadia',
#    'year': '2018',
#    'engine_type': 'V6',
#    'engine_size': '3.6L',
#    'transmission': 'Automatic',
#    'drive_type': 'AWD',
#    'fuel_type': 'Gasoline',
#    'exterior_color': 'Red',
#    'interior_color': 'Standard',
#    'trim_level': 'Standard',
#    'notable_features': ['Backup camera', 'Bluetooth', 'Third-row seating'],
#    'safety_features': ['ABS', 'Airbags', 'Lane-keeping assist'],
#    'price': '3400'}},
#  {'description': "Discover the rugged reliability of the Caterpillar 773, a premium rock truck designed for tough jobs. With its robust build and efficient performance, this machine is perfect for those seeking a powerful workhorse that won't break the bank.",
#   'facets': {'type': 'Machine',
#    'category': 'Rock Truck',
#    'brand': 'Caterpillar',
#    'model': '773',
#    'year': '2016',
#    'engine_type': 'Diesel',
#    'engine_size': 'C6.6 6.6L',
#    'transmission': 'Automatic',
#    'drive_type': '4WD',
#    'fuel_type': 'Diesel',
#    'exterior_color': 'White',
#    'interior_color': 'Standard',
#    'trim_level': 'Standard',
#    'notable_features': ['High Payload Capacity',
#     'Durable Chassis',
#     'Comfortable Operator Station'],
#    'safety_features': ['Stability Control',
#     'Reinforced Structure',
#     'Rollover Protection'],
#    'price': '8600'}},
#  {'description': "This Kubota B2320DTN MFWD Tractor is a reliable workhorse designed for efficiency and durability. With its robust build and versatile capabilities, it's perfect for both small farms and landscaping projects. Experience the power of this affordable tractor, equipped to handle a variety of tasks with ease.",
#   'facets': {'type': 'Machine',
#    'category': 'MFWD Tractor',
#    'brand': 'Kubota',
#    'model': 'B2320DTN',
#    'year': '2010',
#    'engine_type': 'Diesel',
#    'engine_size': 'I4 1.1L',
#    'transmission': 'Hydrostatic',
#    'drive_type': '4WD',
#    'fuel_type': 'Diesel',
#    'exterior_color': 'White',
#    'interior_color': 'Standard',
#    'trim_level': 'Standard',
#    'notable_features': ['Hydrostatic Transmission',
#     'Power Steering',
#     'Mid PTO'],
#    'safety_features': ['Stability Control', 'Reinforced Structure'],
#    'price': '6000'}},
#  {'description': 'Discover the power and reliability of the Case IH OPTUM 270 CVT, a robust 4WD tractor built to handle tough tasks with ease. This machine combines strength and efficiency, making it a budget-friendly choice for any agricultural operation. Its striking green exterior and standard interior ensure you work in style while enjoying a comfortable ride.',
#   'facets': {'type': 'Machine',
#    'category': '4WD Tractor',
#    'brand': 'Case IH',
#    'model': 'OPTUM 270 CVT',
#    'year': '2006',
#    'engine_type': 'I6',
#    'engine_size': '6.7L',
#    'transmission': 'Automatic',
#    'drive_type': '4WD',
#    'fuel_type': 'Diesel',
#    'exterior_color': 'Green',
#    'interior_color': 'Standard',
#    'trim_level': 'Standard',
#    'notable_features': ['GPS Guidance',
#     'Hydraulic Lift',
#     'Comfortable Operator Seat'],
#    'safety_features': ['Stability Control', 'Reinforced Structure'],
#    'price': '3300'}},
#  {'description': "Experience the rugged reliability of the 2018 Ram 1500 Regular Cab, a budget-friendly pickup that combines power and practicality. With its bold black exterior and spacious interior, this truck is perfect for both work and play. Equipped with essential features and a strong V6 engine, it's ready to tackle any challenge you throw its way.",
#   'facets': {'type': 'Vehicle',
#    'category': 'Pickup',
#    'brand': 'Ram',
#    'model': '1500 Regular Cab',
#    'year': '2018',
#    'engine_type': 'V6',
#    'engine_size': '3.6L',
#    'transmission': 'Automatic',
#    'drive_type': 'RWD',
#    'fuel_type': 'Gasoline',
#    'exterior_color': 'Black',
#    'interior_color': 'Standard',
#    'trim_level': 'Standard',
#    'notable_features': ['Bluetooth', 'Backup camera', 'Cruise control'],
#    'safety_features': ['ABS', 'Airbags', 'Stability control'],
#    'price': '10000'}},
#  {'description': 'Experience the epitome of luxury with the 2013 Bentley Mulsanne. This premium sedan boasts a striking black exterior and a sophisticated interior that redefines comfort. With its powerful V8 engine and smooth automatic transmission, driving this vehicle is a pleasure. Enhanced with features like leather seats, navigation, and a premium sound system, it offers a truly refined driving experience. Perfect for those who appreciate elegance and performance.',
#   'facets': {'type': 'Vehicle',
#    'category': 'Sedan',
#    'brand': 'Bentley',
#    'model': 'Mulsanne',
#    'year': '2013',
#    'engine_type': 'V8',
#    'engine_size': '6.75L',
#    'transmission': 'Automatic',
#    'drive_type': 'RWD',
#    'fuel_type': 'Gasoline',
#    'exterior_color': 'Black',
#    'interior_color': 'Standard',
#    'trim_level': 'Standard',
#    'notable_features': ['Leather seats',
#     'Navigation',
#     'Backup camera',
#     'Bluetooth'],
#    'safety_features': ['ABS', 'Airbags', 'Lane-keeping assist'],
#    'price': '4800'}},
#  {'description': "Experience the elegance of the 2007 Cadillac STS, a budget-friendly sedan that combines luxury with performance. Its sleek white exterior and standard interior provide a classic look, while the spacious cabin ensures comfort for all passengers. This vehicle is equipped with a reliable V6 engine, offering a smooth drive whether you're commuting or taking a weekend trip. With features like leather seats and a premium sound system, you'll enjoy every journey in style.",
#   'facets': {'type': 'Vehicle',
#    'category': 'Sedan',
#    'brand': 'Cadillac',
#    'model': 'STS',
#    'year': '2007',
#    'engine_type': 'V6',
#    'engine_size': '3.6L',
#    'transmission': 'Automatic',
#    'drive_type': 'RWD',
#    'fuel_type': 'Gasoline',
#    'exterior_color': 'White',
#    'interior_color': 'Standard',
#    'trim_level': 'Standard',
#    'notable_features': ['Leather seats', 'Premium sound system', 'Navigation'],
#    'safety_features': ['ABS', 'Airbags', 'Stability control'],
#    'price': '3400'}},
#  {'description': 'Experience the rugged reliability of the 2008 Chevrolet Silverado 1500 Regular Cab. This budget-friendly pickup is perfect for both work and play, featuring a robust design and practical features that make it an ideal choice for any task. With its striking red exterior and standard interior, this Silverado combines style with functionality, ensuring you stand out on the road.',
#   'facets': {'type': 'Vehicle',
#    'category': 'Pickup',
#    'brand': 'Chevrolet',
#    'model': 'Silverado 1500 Regular Cab',
#    'year': '2008',
#    'engine_type': 'V8',
#    'engine_size': '4.8L',
#    'transmission': 'Automatic',
#    'drive_type': 'RWD',
#    'fuel_type': 'Gasoline',
#    'exterior_color': 'Red',
#    'interior_color': 'Standard',
#    'trim_level': 'Standard',
#    'notable_features': ['Air Conditioning', 'AM/FM Radio', 'Cruise Control'],
#    'safety_features': ['ABS', 'Airbags', 'Stability Control'],
#    'price': '5900'}},
#  {'description': "Discover the perfect blend of practicality and style with this 2017 Honda Fit. This budget-friendly hatchback is designed for those who value efficiency and versatility. With its spacious interior and compact size, it's ideal for city driving and weekend adventures alike. Enjoy features like a rearview camera and Bluetooth connectivity, making every journey enjoyable and connected.",
#   'facets': {'type': 'Vehicle',
#    'category': 'Hatchback',
#    'brand': 'Honda',
#    'model': 'Fit',
#    'year': '2017',
#    'engine_type': 'I4',
#    'engine_size': '1.5L',
#    'transmission': 'Automatic',
#    'drive_type': 'FWD',
#    'fuel_type': 'Gasoline',
#    'exterior_color': 'Green',
#    'interior_color': 'Standard',
#    'trim_level': 'Standard',
#    'notable_features': ['Bluetooth', 'Rearview camera', 'Spacious cargo area'],
#    'safety_features': ['ABS', 'Airbags', 'Lane-keeping assist'],
#    'price': '6800'}},
#  {'description': "Experience the thrill of driving with this classic 1995 Eagle Talon, a budget-friendly hatchback that combines sporty performance with everyday practicality. With its striking green exterior and standard interior, this vehicle is perfect for those who appreciate retro style and reliable engineering. It's equipped with a peppy I4 2.0L engine and a smooth automatic transmission, making it a joy to drive. This hatchback offers essential safety features and a comfortable ride, making it an excellent choice for both new drivers and seasoned enthusiasts alike.",
#   'facets': {'type': 'Vehicle',
#    'category': 'Hatchback',
#    'brand': 'Eagle',
#    'model': 'Talon',
#    'year': '1995',
#    'engine_type': 'I4',
#    'engine_size': '2.0L',
#    'transmission': 'Automatic',
#    'drive_type': 'FWD',
#    'fuel_type': 'Gasoline',
#    'exterior_color': 'Green',
#    'interior_color': 'Standard',
#    'trim_level': 'Standard',
#    'notable_features': ['Air Conditioning', 'AM/FM Radio', 'Power Windows'],
#    'safety_features': ['ABS', 'Airbags', 'Seatbelts'],
#    'price': '1300'}},
#  {'description': 'Experience the robust performance and reliability of the 2016 GMC Sierra 3500 HD Crew Cab. This premium pickup is designed for those who demand power and versatility, making it perfect for both work and play. With its striking blue exterior and spacious interior, it offers comfort and style in one impressive package.',
#   'facets': {'type': 'Vehicle',
#    'category': 'Pickup',
#    'brand': 'GMC',
#    'model': 'Sierra 3500 HD Crew Cab',
#    'year': '2016',
#    'engine_type': 'V8',
#    'engine_size': '6.0L',
#    'transmission': 'Automatic',
#    'drive_type': '4WD',
#    'fuel_type': 'Gasoline',
#    'exterior_color': 'Blue',
#    'interior_color': 'Standard',
#    'trim_level': 'Standard',
#    'notable_features': ['Leather seats',
#     'Backup camera',
#     'Bluetooth',
#     'Navigation'],
#    'safety_features': ['ABS',
#     'Airbags',
#     'Stability control',
#     'Lane-keeping assist'],
#    'price': '8800'}},
#  {'description': 'Experience the charm of the classic 1992 Toyota Corolla, a reliable and budget-friendly sedan that combines practicality with a touch of nostalgia. Its sleek blue exterior and standard interior offer a timeless look, while its efficient engineering ensures you get the most out of every drive. Perfect for city commuting or weekend getaways, this Corolla is equipped with essential features that make every journey enjoyable.',
#   'facets': {'type': 'Vehicle',
#    'category': 'Sedan, Wagon',
#    'brand': 'Toyota',
#    'model': 'Corolla',
#    'year': '1992',
#    'engine_type': 'I4',
#    'engine_size': '1.6L',
#    'transmission': 'Automatic',
#    'drive_type': 'FWD',
#    'fuel_type': 'Gasoline',
#    'exterior_color': 'Blue',
#    'interior_color': 'Standard',
#    'trim_level': 'Standard',
#    'notable_features': ['Power windows', 'AM/FM radio', 'Air conditioning'],
#    'safety_features': ['ABS', 'Airbags'],
#    'price': '5400'}},
#  {'description': "Discover the rugged reliability of the Kubota M5-091HDRC12, a powerful 4WD tractor designed for heavy-duty tasks. This 2010 model combines efficiency and durability, making it an excellent choice for both agricultural and landscaping needs. With its robust build and versatile capabilities, it's a premium option for those seeking a dependable workhorse.",
#   'facets': {'type': 'Machine',
#    'category': '4WD Tractor',
#    'brand': 'Kubota',
#    'model': 'M5-091HDRC12',
#    'year': '2010',
#    'engine_type': 'Diesel',
#    'engine_size': '4.1L',
#    'transmission': 'Manual',
#    'drive_type': '4WD',
#    'fuel_type': 'Diesel',
#    'exterior_color': 'Black',
#    'interior_color': 'Standard',
#    'trim_level': 'Standard',
#    'notable_features': ['Hydraulic lift', 'PTO', '3-point hitch'],
#    'safety_features': ['Stability control', 'Reinforced structure'],
#    'price': '2600'}},
#  {'description': 'Discover the power and reliability of the Volvo ECR88D, a compact mini excavator designed for efficiency and ease of use. This machine boasts a robust build and is perfect for both professional contractors and DIY enthusiasts. With its striking red exterior and standard interior, it combines functionality with a touch of style. Ideal for tight spaces, this budget-friendly excavator is ready to tackle your next project with confidence.',
#   'facets': {'type': 'Machine',
#    'category': 'Mini Excavator',
#    'brand': 'Volvo',
#    'model': 'ECR88D',
#    'year': '2005',
#    'engine_type': 'Diesel',
#    'engine_size': '4-cylinder 2.0L',
#    'transmission': 'Automatic',
#    'drive_type': '4WD',
#    'fuel_type': 'Diesel',
#    'exterior_color': 'Red',
#    'interior_color': 'Standard',
#    'trim_level': 'Standard',
#    'notable_features': ['Hydraulic quick coupler',
#     'Compact design',
#     'Easy to operate'],
#    'safety_features': ['Stability control',
#     'Reinforced structure',
#     'Operator presence system'],
#    'price': '2900'}},
#  {'description': 'Discover the rugged charm of the 1999 Dodge Dakota Club Cab, a budget-friendly pickup that combines versatility with style. With its striking green exterior and spacious interior, this truck is perfect for both work and play. Enjoy the reliability of its V6 engine and the convenience of an automatic transmission, making every drive a breeze. Ideal for those who appreciate a classic design with modern functionality.',
#   'facets': {'type': 'Vehicle',
#    'category': 'Pickup',
#    'brand': 'Dodge',
#    'model': 'Dakota Club Cab',
#    'year': '1999',
#    'engine_type': 'V6',
#    'engine_size': '3.9L',
#    'transmission': 'Automatic',
#    'drive_type': 'RWD',
#    'fuel_type': 'Gasoline',
#    'exterior_color': 'Green',
#    'interior_color': 'Standard',
#    'trim_level': 'Standard',
#    'notable_features': ['Air Conditioning', 'AM/FM Radio', 'Towing Package'],
#    'safety_features': ['ABS', 'Airbags'],
#    'price': '2300'}},
#  {'description': 'Experience the thrill of open-top driving with this stylish 2006 Mercedes-Benz SLK-Class. This affordable convertible combines luxury and performance, making it a perfect choice for those who appreciate premium German engineering. With its vibrant green exterior and standard interior, it stands out on the road. Enjoy features like leather seats and a navigation system, ensuring every journey is comfortable and convenient.',
#   'facets': {'type': 'Vehicle',
#    'category': 'Convertible',
#    'brand': 'Mercedes-Benz',
#    'model': 'SLK-Class',
#    'year': '2006',
#    'engine_type': 'V6',
#    'engine_size': '3.0L',
#    'transmission': 'Automatic',
#    'drive_type': 'RWD',
#    'fuel_type': 'Gasoline',
#    'exterior_color': 'Green',
#    'interior_color': 'Standard',
#    'trim_level': 'Standard',
#    'notable_features': ['Leather seats', 'Navigation', 'Bluetooth'],
#    'safety_features': ['ABS', 'Airbags', 'Stability control'],
#    'price': '8200'}},
#  {'description': 'Discover the powerful Valtra Orchard 3300, a premium 4WD tractor built for efficiency and reliability in any agricultural setting. This 2017 model boasts a robust design and is equipped with essential features to make your work easier and more productive.',
#   'facets': {'type': 'Machine',
#    'category': '4WD Tractor',
#    'brand': 'Valtra',
#    'model': 'Orchard 3300',
#    'year': '2017',
#    'engine_type': 'I4',
#    'engine_size': '2.4L',
#    'transmission': 'Automatic',
#    'drive_type': '4WD',
#    'fuel_type': 'Diesel',
#    'exterior_color': 'Black',
#    'interior_color': 'Standard',
#    'trim_level': 'Standard',
#    'notable_features': ['Hydraulic lift', 'PTO', 'Cab with air conditioning'],
#    'safety_features': ['Stability control', 'Reinforced structure'],
#    'price': '5800'}},
#  {'description': "This Dynapac CA600PD vibratory compactor is a reliable choice for your construction needs. With its robust performance and durable design, it's perfect for those looking for an affordable yet effective solution for soil compaction. The vibrant green exterior adds a touch of visibility on the job site, ensuring you stand out while getting the job done efficiently.",
#   'facets': {'type': 'Machine',
#    'category': 'Vibratory Compactor',
#    'brand': 'Dynapac',
#    'model': 'CA600PD',
#    'year': '2003',
#    'engine_type': 'Diesel',
#    'engine_size': '4.0L',
#    'transmission': 'Manual',
#    'drive_type': '4WD',
#    'fuel_type': 'Diesel',
#    'exterior_color': 'Green',
#    'interior_color': 'Standard',
# ...
#   'facets': {'type': 'Machine',
#    'category': 'Disc',
#    'brand': 'AMCO',
#    'model': 'J-41 2024',
#    'year': '2009',
#    'engine_type': 'Diesel',
#    'engine_size': 'I4 2.5L',
#    'transmission': 'Automatic',
#    'drive_type': '4WD',
#    'fuel_type': 'Diesel',
#    'exterior_color': 'Green',
#    'interior_color': 'Standard',
#    'trim_level': 'Standard',
#    'notable_features': ['Durable construction',
#     'Easy maneuverability',
#     'User-friendly controls'],
#    'safety_features': ['Stability control',
#     'Reinforced structure',
#     'Basic safety features'],
#    'price': '8300'}},
#  {'description': "The New Holland CX840 is a robust and reliable combine that excels in efficiency and performance. This 2008 model is designed for those who appreciate a budget-friendly option without compromising on quality. With its powerful engine and easy-to-use controls, it's perfect for both seasoned farmers and newcomers alike. Experience the perfect blend of functionality and durability in your agricultural operations.",
#   'facets': {'type': 'Machine',
#    'category': 'Combine',
#    'brand': 'New Holland',
#    'model': 'CX840',
#    'year': '2008',
#    'engine_type': 'Diesel',
#    'engine_size': 'I4 3.0L',
#    'transmission': 'Automatic',
#    'drive_type': '4WD',
#    'fuel_type': 'Diesel',
#    'exterior_color': 'Green',
#    'interior_color': 'Standard',
#    'trim_level': 'Standard',
#    'notable_features': ['Automatic controls',
#     'High-capacity grain tank',
#     'Adjustable header'],
#    'safety_features': ['Stability control',
#     'Reinforced structure',
#     'Emergency stop'],
#    'price': '1100'}},
#  {'description': "Discover the power and reliability of the AGCO RT140, a robust 4WD tractor designed for those who demand performance without compromise. This model combines functionality with an affordable price point, making it an excellent choice for both professionals and enthusiasts. With its durable white exterior and standard interior, it's built to tackle any job with ease.",
#   'facets': {'type': 'Machine',
#    'category': '4WD Tractor',
#    'brand': 'AGCO',
#    'model': 'RT140',
#    'year': '2018',
#    'engine_type': 'Diesel',
#    'engine_size': 'I4 2.4L',
#    'transmission': 'Automatic',
#    'drive_type': '4WD',
#    'fuel_type': 'Diesel',
#    'exterior_color': 'White',
#    'interior_color': 'Standard',
#    'trim_level': 'Standard',
#    'notable_features': ['Hydraulic lift', 'Rear PTO', 'Comfortable seating'],
#    'safety_features': ['Stability control',
#     'Reinforced structure',
#     'Rollover protection'],
#    'price': '5300'}},
#  {'description': 'Discover the rugged charm of the 2019 Ram 1500 Classic Quad Cab, a perfect blend of capability and comfort. This pickup is designed for those who appreciate a robust ride, featuring a spacious interior and a striking black exterior. With its premium build quality and reliable performance, this vehicle is an excellent choice for both work and play.',
#   'facets': {'type': 'Vehicle',
#    'category': 'Pickup',
#    'brand': 'Ram',
#    'model': '1500 Classic Quad Cab',
#    'year': '2019',
#    'engine_type': 'V8',
#    'engine_size': '5.7L',
#    'transmission': 'Automatic',
#    'drive_type': '4WD',
#    'fuel_type': 'Gasoline',
#    'exterior_color': 'Black',
#    'interior_color': 'Standard',
#    'trim_level': 'Standard',
#    'notable_features': ['Bluetooth', 'Backup camera', 'Cruise control'],
#    'safety_features': ['ABS', 'Airbags', 'Stability control'],
#    'price': '7800'}},
#  {'description': 'The 2005 Sunflower 5054-62 cultivator is an excellent choice for those seeking a reliable and efficient machine for their farming needs. With its robust build and user-friendly design, this cultivator ensures a smooth operation in the field, making it a budget-friendly option for both small and large farms. Its black exterior adds a touch of professionalism, while the standard interior provides comfort during use.',
#   'facets': {'type': 'Machine',
#    'category': 'Cultivator',
#    'brand': 'Sunflower',
#    'model': '5054-62',
#    'year': '2005',
#    'engine_type': 'Diesel',
#    'engine_size': 'I4 2.5L',
#    'transmission': 'Manual',
#    'drive_type': '4WD',
#    'fuel_type': 'Diesel',
#    'exterior_color': 'Black',
#    'interior_color': 'Standard',
#    'trim_level': 'Standard',
#    'notable_features': ['Reinforced structure', 'Adjustable tines'],
#    'safety_features': ['Stability control', 'Basic safety features'],
#    'price': '1100'}},
#  {'description': 'Explore the robust capabilities of the Fiat-Hitachi EX165LC, a dependable hydraulic excavator designed for efficiency and power. This machine boasts a striking blue exterior and a standard interior that combines functionality with comfort. Ideal for construction and excavation projects, it offers a budget-friendly solution without compromising on performance. Get ready to tackle your toughest jobs with ease!',
#   'facets': {'type': 'Machine',
#    'category': 'Hydraulic Excavator',
#    'brand': 'Fiat-Hitachi',
#    'model': 'EX165LC',
#    'year': '2016',
#    'engine_type': 'Diesel',
#    'engine_size': '4.5L',
#    'transmission': 'Automatic',
#    'drive_type': '4WD',
#    'fuel_type': 'Diesel',
#    'exterior_color': 'Blue',
#    'interior_color': 'Standard',
#    'trim_level': 'Standard',
#    'notable_features': ['Hydraulic Boom',
#     'Quick Coupler',
#     'Auxiliary Hydraulics'],
#    'safety_features': ['Stability Control',
#     'Reinforced Structure',
#     'Operator Protection'],
#    'price': '8900'}},
#  {'description': 'Discover the power and reliability of the John Deere 2154D Road Builder, a budget-friendly hydraulic excavator built for efficiency and performance. This robust machine features a sleek black exterior and is designed to tackle tough jobs with ease, making it a great choice for contractors and builders alike.',
#   'facets': {'type': 'Machine',
#    'category': 'Hydraulic Excavator',
#    'brand': 'John Deere',
#    'model': '2154D Road Builder',
#    'year': '2013',
#    'engine_type': 'Diesel',
#    'engine_size': '4.5L',
#    'transmission': 'Automatic',
#    'drive_type': '4WD',
#    'fuel_type': 'Diesel',
#    'exterior_color': 'Black',
#    'interior_color': 'Standard',
#    'trim_level': 'Standard',
#    'notable_features': ['Hydraulic controls',
#     'Durable construction',
#     'Adjustable boom'],
#    'safety_features': ['Stability control',
#     'Reinforced structure',
#     'Operator presence system'],
#    'price': '5100'}},
#  {'description': 'Discover the power and reliability of the Gehl 4640E, a robust skid steer loader that’s perfect for both professional and personal projects. With its vibrant red exterior and dependable performance, this machine is designed to tackle tough jobs with ease. Offering a budget-friendly option for operators looking to enhance their equipment lineup, the Gehl 4640E boasts a standard trim level and essential features that make it a practical choice for any worksite.',
#   'facets': {'type': 'Machine',
#    'category': 'Skid Steer Loader',
#    'brand': 'Gehl',
#    'model': '4640E',
#    'year': '2004',
#    'engine_type': 'Diesel',
#    'engine_size': 'I4 2.4L',
#    'transmission': 'Automatic',
#    'drive_type': '4WD',
#    'fuel_type': 'Diesel',
#    'exterior_color': 'Red',
#    'interior_color': 'Standard',
#    'trim_level': 'Standard',
#    'notable_features': ['Standard Features',
#     'Hydraulic lift',
#     'Quick attach system'],
#    'safety_features': ['Stability control',
#     'Reinforced structure',
#     'Safety interlock system'],
#    'price': '3100'}},
#  {'description': 'Discover the power and versatility of the John Deere 544J Powerllel w/Coupler, a reliable machine designed for heavy-duty tasks. This budget-friendly wheel loader is equipped to handle a range of projects with ease, making it a great choice for contractors and landscapers alike. Its robust build and efficient performance ensure that you can tackle any job without breaking a sweat.',
#   'facets': {'type': 'Machine',
#    'category': 'Wheel Loader',
#    'brand': 'John Deere',
#    'model': '544J Powerllel w/Coupler',
#    'year': '2008',
#    'engine_type': 'Diesel',
#    'engine_size': '4.5L',
#    'transmission': 'Automatic',
#    'drive_type': '4WD',
#    'fuel_type': 'Diesel',
#    'exterior_color': 'Black',
#    'interior_color': 'Standard',
#    'trim_level': 'Standard',
#    'notable_features': ['Hydraulic coupler',
#     'Loader bucket',
#     'Operator-friendly controls'],
#    'safety_features': ['Stability control',
#     'Reinforced structure',
#     'Rearview camera'],
#    'price': '8900'}},
#  {'description': 'Experience the thrill of open-air driving with this classic 2000 Porsche Boxster. This affordable convertible combines sporty performance with timeless style, making it a perfect choice for those who seek adventure without compromising on quality. With its striking red exterior and comfortable interior, this vehicle is ready to turn heads on the road.',
#   'facets': {'type': 'Vehicle',
#    'category': 'Convertible',
#    'brand': 'Porsche',
#    'model': 'Boxster',
#    'year': '2000',
#    'engine_type': 'Flat-6',
#    'engine_size': '2.7L',
#    'transmission': 'Manual',
#    'drive_type': 'RWD',
#    'fuel_type': 'Gasoline',
#    'exterior_color': 'Red',
#    'interior_color': 'Standard',
#    'trim_level': 'Standard',
#    'notable_features': ['Leather seats',
#     'Navigation',
#     'CD player',
#     'Power windows'],
#    'safety_features': ['ABS', 'Airbags', 'Stability control'],
#    'price': '6900'}},
#  {'description': 'Experience the versatility of the 2004 GMC Envoy XUV, a budget-friendly SUV that combines rugged capability with everyday comfort. With its striking red exterior and spacious interior, this vehicle is perfect for both city driving and outdoor adventures. Enjoy features like a smooth ride, ample cargo space, and a host of safety technologies that ensure peace of mind on every journey.',
#   'facets': {'type': 'Vehicle',
#    'category': 'SUV',
#    'brand': 'GMC',
#    'model': 'Envoy XUV',
#    'year': '2004',
#    'engine_type': 'V6',
#    'engine_size': '4.2L',
#    'transmission': 'Automatic',
#    'drive_type': 'AWD',
#    'fuel_type': 'Gasoline',
#    'exterior_color': 'Red',
#    'interior_color': 'Standard',
#    'trim_level': 'Standard',
#    'notable_features': ['Leather seats',
#     'Navigation',
#     'Backup camera',
#     'Bluetooth'],
#    'safety_features': ['ABS',
#     'Airbags',
#     'Stability control',
#     'Traction control'],
#    'price': '3800'}},
#  {'description': "Discover the power and reliability of the 2018 Volvo G960B Motor Grader. This premium machine is designed for precision and efficiency, making it an excellent choice for any construction project. With its robust build and advanced features, it's perfect for those looking for a dependable workhorse that won't break the bank.",
#   'facets': {'type': 'Machine',
#    'category': 'Motor Grader',
#    'brand': 'Volvo',
#    'model': 'G960B',
#    'year': '2018',
#    'engine_type': 'Diesel',
#    'engine_size': '6.1L',
#    'transmission': 'Automatic',
#    'drive_type': '4WD',
#    'fuel_type': 'Diesel',
#    'exterior_color': 'Blue',
#    'interior_color': 'Standard',
#    'trim_level': 'Standard',
#    'notable_features': ['Hydraulic controls',
#     'Adjustable blade',
#     'Comfortable operator seat'],
#    'safety_features': ['Stability control',
#     'Reinforced structure',
#     'Rearview camera'],
#    'price': '5000'}},
#  {'description': 'Experience the power and reliability of the Kubota M6800, a robust 4WD tractor designed for both efficiency and performance. With its durable construction and premium features, this machine is perfect for handling tough tasks while providing exceptional comfort and control. Ideal for those seeking a dependable workhorse at an affordable value.',
#   'facets': {'type': 'Machine',
#    'category': '4WD Tractor',
#    'brand': 'Kubota',
#    'model': 'M6800',
#    'year': '2007',
#    'engine_type': 'Diesel',
#    'engine_size': 'I4 2.4L',
#    'transmission': 'Manual',
#    'drive_type': '4WD',
#    'fuel_type': 'Diesel',
#    'exterior_color': 'Green',
#    'interior_color': 'Standard',
#    'trim_level': 'Standard',
#    'notable_features': ['Power Steering', 'Hydraulic Lift', 'Rear PTO'],
#    'safety_features': ['Stability Control', 'Reinforced Structure'],
#    'price': '7700'}},
#  {'description': 'Experience the joy of driving with this classic 1994 MAZDA MX-5 Miata. This budget-friendly convertible offers a spirited performance with its lightweight design and nimble handling, perfect for those sunny days. Enjoy the thrill of open-air driving in a vehicle that combines style and fun in one compact package.',
#   'facets': {'type': 'Vehicle',
#    'category': 'Convertible',
#    'brand': 'MAZDA',
#    'model': 'MX-5 Miata',
#    'year': '1994',
#    'engine_type': 'I4',
#    'engine_size': '1.8L',
#    'transmission': 'Manual',
#    'drive_type': 'RWD',
#    'fuel_type': 'Gasoline',
#    'exterior_color': 'Black',
#    'interior_color': 'Standard',
#    'trim_level': 'Standard',
#    'notable_features': ['Leather seats', 'Bluetooth', 'AM/FM radio'],
#    'safety_features': ['ABS', 'Airbags', 'Stability control'],
#    'price': '4400'}},
#  {'description': "Discover the rugged charm of this 2005 Chevrolet Colorado Regular Cab. With its striking green exterior and reliable performance, this budget-friendly pickup is perfect for both work and play. Enjoy the spacious interior and standard features that make every drive comfortable. Whether you're hauling gear or cruising through town, this Colorado is ready for any adventure.",
#   'facets': {'type': 'Vehicle',
#    'category': 'Pickup',
#    'brand': 'Chevrolet',
#    'model': 'Colorado Regular Cab',
#    'year': '2005',
#    'engine_type': 'I5',
#    'engine_size': '2.8L',
#    'transmission': 'Automatic',
#    'drive_type': 'RWD',
#    'fuel_type': 'Gasoline',
#    'exterior_color': 'Green',
#    'interior_color': 'Standard',
#    'trim_level': 'Standard',
#    'notable_features': ['Air Conditioning', 'AM/FM Radio', 'Bed Liner'],
#    'safety_features': ['ABS', 'Airbags', 'Stability Control'],
#    'price': '2700'}},
#  {'description': 'Experience the power and reliability of the Case IH MAXXUM 135, a robust 4WD tractor designed for both farming and heavy-duty tasks. Its premium build quality and efficient performance make it an excellent choice for those seeking a dependable workhorse. With its striking blue exterior and standard interior, this machine not only performs well but also looks great in any field. Ideal for budget-conscious buyers who demand quality without compromise.',
#   'facets': {'type': 'Machine',
#    'category': '4WD Tractor',
#    'brand': 'Case IH',
#    'model': 'MAXXUM 135',
#    'year': '2005',
#    'engine_type': 'Diesel',
#    'engine_size': '4.5L',
#    'transmission': 'Manual',
#    'drive_type': '4WD',
#    'fuel_type': 'Diesel',
#    'exterior_color': 'Blue',
#    'interior_color': 'Standard',
#    'trim_level': 'Standard',
#    'notable_features': ['Power steering',
#     'Hydraulic lift',
#     'Front loader compatible'],
#    'safety_features': ['Stability control',
#     'Reinforced structure',
#     'Rollover protection'],
#    'price': '5900'}},
#  {'description': "Discover the spacious and versatile GMC Savana 1500 Passenger, perfect for family outings or group travels. This reliable van combines comfort with functionality, making it an excellent choice for those seeking a budget-friendly vehicle that doesn’t compromise on quality. With its robust design and ample seating, you'll enjoy every journey.",
#   'facets': {'type': 'Vehicle',
#    'category': 'Van/Minivan',
#    'brand': 'GMC',
#    'model': 'Savana 1500 Passenger',
#    'year': '2001',
#    'engine_type': 'V8',
#    'engine_size': '5.7L',
#    'transmission': 'Automatic',
#    'drive_type': 'RWD',
#    'fuel_type': 'Gasoline',
#    'exterior_color': 'Black',
#    'interior_color': 'Standard',
#    'trim_level': 'Standard',
#    'notable_features': ['Spacious interior',
#     'Air conditioning',
#     'AM/FM radio'],
#    'safety_features': ['ABS', 'Airbags', 'Stability control'],
#    'price': '2500'}},
#  ...]

# %%
len(processed_data)
# Out:
# 5000

# %%
type_counts = Counter(item['facets']['type'] for item in processed_data)
type_counts
# Out:
# Counter({'Vehicle': 2500, 'Machine': 2500})

# %%
df = pd.DataFrame(processed_data)

# %%
df.to_json("./data/processed_vehicle_machine_data.json", orient="records", indent=2)
