# %%
import json
import uuid

import pandas as pd
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.

# %%
import sys
import os

# Get the current working directory and the relative path to your module
module_path = os.path.abspath(os.path.join("..", ".."))
if module_path not in sys.path:
    sys.path.append(module_path)

# Now you can import your module
from src.api.repository.search import SearchRepo

# %%
es = SearchRepo()
# Out:
# Connected to Elasticsearch!
# {'cluster_name': 'docker-cluster',
#  'cluster_uuid': '9I9q3mFYSISbvBg75cK23A',
#  'name': '5eeda383872f',
#  'tagline': 'You Know, for Search',
#  'version': {'build_date': '2024-08-05T10:05:34.233336849Z',
#              'build_flavor': 'default',
#              'build_hash': '1a77947f34deddb41af25e6f0ddb8e830159c179',
#              'build_snapshot': False,
#              'build_type': 'docker',
#              'lucene_version': '9.11.1',
#              'minimum_index_compatibility_version': '7.0.0',
#              'minimum_wire_compatibility_version': '7.17.0',
#              'number': '8.15.0'}}

# %%
idx="vehicle"

# %% [markdown]
# # 1. Extract Data

# %%
df = pd.read_json("./data/processed_vehicle_machine_data.json",  orient='records')

# %%
df
# Out:
#                                             description  \
# 0     Experience the thrill of driving with this 200...
# 1     Experience the future of driving with the 2014...
# 2     Discover the power and reliability of the JCB ...
# 3     Discover the Ezee-On 5537-56-13-10, a robust c...
# 4     Discover the power and reliability of the Cate...
# ...                                                 ...
# 4995  Experience the thrill of the road with this 20...
# 4996  Experience the power and efficiency of the New...
# 4997  Discover the rugged reliability of the Case IH...
# 4998  Experience the thrill of driving with this sty...
# 4999  Experience the charm of the classic 1993 Oldsm...
#
#                                                  facets
# 0     {'type': 'Vehicle', 'category': 'Coupe', 'bran...
# 1     {'type': 'Vehicle', 'category': 'Hatchback', '...
# 2     {'type': 'Machine', 'category': 'Hydraulic Exc...
# 3     {'type': 'Machine', 'category': 'Cultivator', ...
# 4     {'type': 'Machine', 'category': 'Shovel', 'bra...
# ...                                                 ...
# 4995  {'type': 'Vehicle', 'category': 'Sedan', 'bran...
# 4996  {'type': 'Machine', 'category': 'Combine', 'br...
# 4997  {'type': 'Machine', 'category': '4WD Tractor',...
# 4998  {'type': 'Vehicle', 'category': 'Coupe, Conver...
# 4999  {'type': 'Vehicle', 'category': 'Coupe, Sedan'...
#
# [5000 rows x 2 columns]

# %%
df.iloc[0]["facets"]
# Out:
# {'type': 'Vehicle',
#  'category': 'Coupe',
#  'brand': 'Lotus',
#  'model': 'Exige S',
#  'year': '2008',
#  'engine_type': 'I4',
#  'engine_size': '1.8L',
#  'transmission': 'Manual',
#  'drive_type': 'RWD',
#  'fuel_type': 'Gasoline',
#  'exterior_color': 'Red',
#  'interior_color': 'Standard',
#  'trim_level': 'Standard',
#  'notable_features': ['Leather seats', 'Navigation', 'Bluetooth'],
#  'safety_features': ['ABS', 'Airbags', 'Stability control'],
#  'price': '5700'}

# %% [markdown]
# # 2. Transform Data

# %%
def process_hierarchy(hierarchy, field_name="type"):
    accumulated_path = ""
    result = []
    for level, entry in enumerate(hierarchy, start=1):
        accumulated_path = f"{accumulated_path}/{entry['name']}" if accumulated_path else entry["name"]
        result.append({
            "id": entry.get("id"),
            "name": field_name,
            "value": accumulated_path,
            "type": entry["type"],
            #"level": level
        })
    return result

# %%
def flatten_list(nested_list):
    flattened = []
    for item in nested_list:
        if isinstance(item, list):
            # Recursively flatten the nested list
            flattened.extend(flatten_list(item))
        else:
            # Append individual items
            flattened.append(item)
    return flattened

# %%
def transform(input: dict):
    number_list = ["price"]
    path_list = ["type", "category", "brand", "model"]

    description = input["description"]
    facets = input["facets"]

    term_facets = [
        {"name": k, "value": v}
        for k, v in facets.items()
        if k not in number_list and k not in path_list
    ]

    number_facets = [
        {"name": k, "value": v} for k, v in facets.items() if k in number_list
    ]

    hierarchy_type = [
        {"name": "Type", "type": "root"},
        {"name": facets["type"], "type": "type"},
        {"name": facets["category"], "type": "category"},
    ]

    hierarchy_brand = [
        {"name": "Brand", "type": "root"},
        {"name": facets["brand"], "type": "brand"},
        {"name": facets["model"], "type": "model"},
    ]

    path_facets = [process_hierarchy(hierarchy_type, field_name="type")] + [
        process_hierarchy(hierarchy_brand, field_name="brand")
    ]

    full_text = description

    full_text_boosted = [v for k, v in facets.items() if k not in number_list]
    full_text_boosted_list = flatten_list(full_text_boosted)
    full_text_boosted_str = " ".join(full_text_boosted_list)

    _id = str(uuid.uuid4())

    output = {
        "termFacetData": term_facets,
        "numberFacetData": number_facets,
        "pathFacetData": path_facets,
        "search_data": {
            "full_text": full_text,
            "full_text_boosted": full_text_boosted_str,
        },
        "completion_terms": [{"tag": v} for v in full_text_boosted_list],
        "suggestion_terms": full_text_boosted_list,  # to improve
        "id": _id,
    }

    return output

# %%
transform(df.iloc[0])
# Out:
# {'termFacetData': [{'name': 'year', 'value': '2008'},
#   {'name': 'engine_type', 'value': 'I4'},
#   {'name': 'engine_size', 'value': '1.8L'},
#   {'name': 'transmission', 'value': 'Manual'},
#   {'name': 'drive_type', 'value': 'RWD'},
#   {'name': 'fuel_type', 'value': 'Gasoline'},
#   {'name': 'exterior_color', 'value': 'Red'},
#   {'name': 'interior_color', 'value': 'Standard'},
#   {'name': 'trim_level', 'value': 'Standard'},
#   {'name': 'notable_features',
#    'value': ['Leather seats', 'Navigation', 'Bluetooth']},
#   {'name': 'safety_features',
#    'value': ['ABS', 'Airbags', 'Stability control']}],
#  'numberFacetData': [{'name': 'price', 'value': '5700'}],
#  'pathFacetData': [[{'id': None,
#     'name': 'type',
#     'value': 'Type',
#     'type': 'root'},
#    {'id': None, 'name': 'type', 'value': 'Type/Vehicle', 'type': 'type'},
#    {'id': None,
#     'name': 'type',
#     'value': 'Type/Vehicle/Coupe',
#     'type': 'category'}],
#   [{'id': None, 'name': 'brand', 'value': 'Brand', 'type': 'root'},
#    {'id': None, 'name': 'brand', 'value': 'Brand/Lotus', 'type': 'brand'},
#    {'id': None,
#     'name': 'brand',
#     'value': 'Brand/Lotus/Exige S',
#     'type': 'model'}]],
#  'search_data': {'full_text': 'Experience the thrill of driving with this 2008 Lotus Exige S, a budget-friendly sports coupe that combines lightweight design with exhilarating performance. With its striking red exterior and agile handling, this vehicle promises an unforgettable ride. Perfect for enthusiasts seeking a unique driving experience without breaking the bank.',
#   'full_text_boosted': 'Vehicle Coupe Lotus Exige S 2008 I4 1.8L Manual RWD Gasoline Red Standard Standard Leather seats Navigation Bluetooth ABS Airbags Stability control'},
#  'completion_terms': [{'tag': 'Vehicle'},
#   {'tag': 'Coupe'},
#   {'tag': 'Lotus'},
#   {'tag': 'Exige S'},
#   {'tag': '2008'},
#   {'tag': 'I4'},
#   {'tag': '1.8L'},
#   {'tag': 'Manual'},
#   {'tag': 'RWD'},
#   {'tag': 'Gasoline'},
#   {'tag': 'Red'},
#   {'tag': 'Standard'},
#   {'tag': 'Standard'},
#   {'tag': 'Leather seats'},
#   {'tag': 'Navigation'},
#   {'tag': 'Bluetooth'},
#   {'tag': 'ABS'},
#   {'tag': 'Airbags'},
#   {'tag': 'Stability control'}],
#  'suggestion_terms': ['Vehicle',
#   'Coupe',
#   'Lotus',
#   'Exige S',
#   '2008',
#   'I4',
#   '1.8L',
#   'Manual',
#   'RWD',
#   'Gasoline',
#   'Red',
#   'Standard',
#   'Standard',
#   'Leather seats',
#   'Navigation',
#   'Bluetooth',
#   'ABS',
#   'Airbags',
#   'Stability control'],
#  'id': '12683a27-90d8-4106-ad15-95a9e53b68dc'}

# %%
documents = [transform(row) for index, row in df.iterrows()]

# %%
documents
# Out:
# [{'termFacetData': [{'name': 'year', 'value': '2008'},
#    {'name': 'engine_type', 'value': 'I4'},
#    {'name': 'engine_size', 'value': '1.8L'},
#    {'name': 'transmission', 'value': 'Manual'},
#    {'name': 'drive_type', 'value': 'RWD'},
#    {'name': 'fuel_type', 'value': 'Gasoline'},
#    {'name': 'exterior_color', 'value': 'Red'},
#    {'name': 'interior_color', 'value': 'Standard'},
#    {'name': 'trim_level', 'value': 'Standard'},
#    {'name': 'notable_features',
#     'value': ['Leather seats', 'Navigation', 'Bluetooth']},
#    {'name': 'safety_features',
#     'value': ['ABS', 'Airbags', 'Stability control']}],
#   'numberFacetData': [{'name': 'price', 'value': '5700'}],
#   'pathFacetData': [[{'id': None,
#      'name': 'type',
#      'value': 'Type',
#      'type': 'root'},
#     {'id': None, 'name': 'type', 'value': 'Type/Vehicle', 'type': 'type'},
#     {'id': None,
#      'name': 'type',
#      'value': 'Type/Vehicle/Coupe',
#      'type': 'category'}],
#    [{'id': None, 'name': 'brand', 'value': 'Brand', 'type': 'root'},
#     {'id': None, 'name': 'brand', 'value': 'Brand/Lotus', 'type': 'brand'},
#     {'id': None,
#      'name': 'brand',
#      'value': 'Brand/Lotus/Exige S',
#      'type': 'model'}]],
#   'search_data': {'full_text': 'Experience the thrill of driving with this 2008 Lotus Exige S, a budget-friendly sports coupe that combines lightweight design with exhilarating performance. With its striking red exterior and agile handling, this vehicle promises an unforgettable ride. Perfect for enthusiasts seeking a unique driving experience without breaking the bank.',
#    'full_text_boosted': 'Vehicle Coupe Lotus Exige S 2008 I4 1.8L Manual RWD Gasoline Red Standard Standard Leather seats Navigation Bluetooth ABS Airbags Stability control'},
#   'completion_terms': [{'tag': 'Vehicle'},
#    {'tag': 'Coupe'},
#    {'tag': 'Lotus'},
#    {'tag': 'Exige S'},
#    {'tag': '2008'},
#    {'tag': 'I4'},
#    {'tag': '1.8L'},
#    {'tag': 'Manual'},
#    {'tag': 'RWD'},
#    {'tag': 'Gasoline'},
#    {'tag': 'Red'},
#    {'tag': 'Standard'},
#    {'tag': 'Standard'},
#    {'tag': 'Leather seats'},
#    {'tag': 'Navigation'},
#    {'tag': 'Bluetooth'},
#    {'tag': 'ABS'},
#    {'tag': 'Airbags'},
#    {'tag': 'Stability control'}],
#   'suggestion_terms': ['Vehicle',
#    'Coupe',
#    'Lotus',
#    'Exige S',
#    '2008',
#    'I4',
#    '1.8L',
#    'Manual',
#    'RWD',
#    'Gasoline',
#    'Red',
#    'Standard',
#    'Standard',
#    'Leather seats',
#    'Navigation',
#    'Bluetooth',
#    'ABS',
#    'Airbags',
#    'Stability control'],
#   'id': 'e880f9d6-7937-4696-8bb5-0cd0e8517ec1'},
#  {'termFacetData': [{'name': 'year', 'value': '2014'},
#    {'name': 'engine_type', 'value': 'Electric'},
#    {'name': 'engine_size', 'value': 'N/A'},
#    {'name': 'transmission', 'value': 'Automatic'},
#    {'name': 'drive_type', 'value': 'RWD'},
#    {'name': 'fuel_type', 'value': 'Electric'},
#    {'name': 'exterior_color', 'value': 'Red'},
#    {'name': 'interior_color', 'value': 'Standard'},
#    {'name': 'trim_level', 'value': 'Standard'},
#    {'name': 'notable_features',
#     'value': ['Navigation', 'Backup camera', 'Bluetooth']},
#    {'name': 'safety_features',
#     'value': ['ABS', 'Airbags', 'Lane-keeping assist']}],
#   'numberFacetData': [{'name': 'price', 'value': '8600'}],
#   'pathFacetData': [[{'id': None,
#      'name': 'type',
#      'value': 'Type',
#      'type': 'root'},
#     {'id': None, 'name': 'type', 'value': 'Type/Vehicle', 'type': 'type'},
#     {'id': None,
#      'name': 'type',
#      'value': 'Type/Vehicle/Hatchback',
#      'type': 'category'}],
#    [{'id': None, 'name': 'brand', 'value': 'Brand', 'type': 'root'},
#     {'id': None, 'name': 'brand', 'value': 'Brand/BMW', 'type': 'brand'},
#     {'id': None, 'name': 'brand', 'value': 'Brand/BMW/i3', 'type': 'model'}]],
#   'search_data': {'full_text': 'Experience the future of driving with the 2014 BMW i3, a compact hatchback that combines sustainability with style. This budget-friendly electric vehicle boasts a striking red exterior and a modern interior that welcomes you with comfort and technology. Perfect for city driving, it offers nimble handling and an eco-conscious ride, making it an excellent choice for the environmentally aware driver.',
#    'full_text_boosted': 'Vehicle Hatchback BMW i3 2014 Electric N/A Automatic RWD Electric Red Standard Standard Navigation Backup camera Bluetooth ABS Airbags Lane-keeping assist'},
#   'completion_terms': [{'tag': 'Vehicle'},
#    {'tag': 'Hatchback'},
#    {'tag': 'BMW'},
#    {'tag': 'i3'},
#    {'tag': '2014'},
#    {'tag': 'Electric'},
#    {'tag': 'N/A'},
#    {'tag': 'Automatic'},
#    {'tag': 'RWD'},
#    {'tag': 'Electric'},
#    {'tag': 'Red'},
#    {'tag': 'Standard'},
#    {'tag': 'Standard'},
#    {'tag': 'Navigation'},
#    {'tag': 'Backup camera'},
#    {'tag': 'Bluetooth'},
#    {'tag': 'ABS'},
#    {'tag': 'Airbags'},
#    {'tag': 'Lane-keeping assist'}],
#   'suggestion_terms': ['Vehicle',
#    'Hatchback',
#    'BMW',
#    'i3',
#    '2014',
#    'Electric',
#    'N/A',
#    'Automatic',
#    'RWD',
#    'Electric',
#    'Red',
#    'Standard',
#    'Standard',
#    'Navigation',
#    'Backup camera',
#    'Bluetooth',
#    'ABS',
#    'Airbags',
#    'Lane-keeping assist'],
#   'id': 'd9b7da79-04d1-4fa7-8995-649c4e9bb15c'},
#  {'termFacetData': [{'name': 'year', 'value': '2001'},
#    {'name': 'engine_type', 'value': 'Diesel'},
#    {'name': 'engine_size', 'value': '4.4L'},
#    {'name': 'transmission', 'value': 'Automatic'},
#    {'name': 'drive_type', 'value': '4WD'},
#    {'name': 'fuel_type', 'value': 'Diesel'},
#    {'name': 'exterior_color', 'value': 'Blue'},
#    {'name': 'interior_color', 'value': 'Standard'},
#    {'name': 'trim_level', 'value': 'Standard'},
#    {'name': 'notable_features',
#     'value': ['Hydraulic arm', 'Robust chassis', 'Standard controls']},
#    {'name': 'safety_features',
#     'value': ['Stability control', 'Reinforced structure', 'Emergency stop']}],
#   'numberFacetData': [{'name': 'price', 'value': '1200'}],
#   'pathFacetData': [[{'id': None,
#      'name': 'type',
#      'value': 'Type',
#      'type': 'root'},
#     {'id': None, 'name': 'type', 'value': 'Type/Machine', 'type': 'type'},
#     {'id': None,
#      'name': 'type',
#      'value': 'Type/Machine/Hydraulic Excavator',
#      'type': 'category'}],
#    [{'id': None, 'name': 'brand', 'value': 'Brand', 'type': 'root'},
#     {'id': None, 'name': 'brand', 'value': 'Brand/JCB', 'type': 'brand'},
#     {'id': None,
#      'name': 'brand',
#      'value': 'Brand/JCB/JS200NC',
#      'type': 'model'}]],
#   'search_data': {'full_text': 'Discover the power and reliability of the JCB JS200NC, a budget-friendly hydraulic excavator built for efficiency and performance. This robust machine is perfect for construction and excavation tasks, offering a dependable solution for your heavy-duty needs. Its striking blue exterior not only stands out on the job site but also reflects the quality craftsmanship of JCB. Experience the ease of operation with its standard features designed to enhance productivity.',
#    'full_text_boosted': 'Machine Hydraulic Excavator JCB JS200NC 2001 Diesel 4.4L Automatic 4WD Diesel Blue Standard Standard Hydraulic arm Robust chassis Standard controls Stability control Reinforced structure Emergency stop'},
#   'completion_terms': [{'tag': 'Machine'},
#    {'tag': 'Hydraulic Excavator'},
#    {'tag': 'JCB'},
#    {'tag': 'JS200NC'},
#    {'tag': '2001'},
#    {'tag': 'Diesel'},
#    {'tag': '4.4L'},
#    {'tag': 'Automatic'},
#    {'tag': '4WD'},
#    {'tag': 'Diesel'},
#    {'tag': 'Blue'},
#    {'tag': 'Standard'},
#    {'tag': 'Standard'},
#    {'tag': 'Hydraulic arm'},
#    {'tag': 'Robust chassis'},
#    {'tag': 'Standard controls'},
#    {'tag': 'Stability control'},
#    {'tag': 'Reinforced structure'},
#    {'tag': 'Emergency stop'}],
#   'suggestion_terms': ['Machine',
#    'Hydraulic Excavator',
#    'JCB',
#    'JS200NC',
#    '2001',
#    'Diesel',
#    '4.4L',
#    'Automatic',
#    '4WD',
#    'Diesel',
#    'Blue',
#    'Standard',
#    'Standard',
#    'Hydraulic arm',
#    'Robust chassis',
#    'Standard controls',
#    'Stability control',
#    'Reinforced structure',
#    'Emergency stop'],
#   'id': 'f98c0044-85a7-483f-b059-409f77c245f9'},
#  {'termFacetData': [{'name': 'year', 'value': '2007'},
#    {'name': 'engine_type', 'value': 'Diesel'},
#    {'name': 'engine_size', 'value': 'I4 2.2L'},
#    {'name': 'transmission', 'value': 'Automatic'},
#    {'name': 'drive_type', 'value': '4WD'},
#    {'name': 'fuel_type', 'value': 'Diesel'},
#    {'name': 'exterior_color', 'value': 'Blue'},
#    {'name': 'interior_color', 'value': 'Standard'},
#    {'name': 'trim_level', 'value': 'Standard'},
#    {'name': 'notable_features',
#     'value': ['Adjustable tines', 'User-friendly controls', 'Compact design']},
#    {'name': 'safety_features',
#     'value': ['Stability control', 'Reinforced structure']}],
#   'numberFacetData': [{'name': 'price', 'value': '5700'}],
#   'pathFacetData': [[{'id': None,
#      'name': 'type',
#      'value': 'Type',
#      'type': 'root'},
#     {'id': None, 'name': 'type', 'value': 'Type/Machine', 'type': 'type'},
#     {'id': None,
#      'name': 'type',
#      'value': 'Type/Machine/Cultivator',
#      'type': 'category'}],
#    [{'id': None, 'name': 'brand', 'value': 'Brand', 'type': 'root'},
#     {'id': None, 'name': 'brand', 'value': 'Brand/Ezee-On', 'type': 'brand'},
#     {'id': None,
#      'name': 'brand',
#      'value': 'Brand/Ezee-On/5537-56-13-10',
#      'type': 'model'}]],
#   'search_data': {'full_text': 'Discover the Ezee-On 5537-56-13-10, a robust cultivator designed for efficiency and ease of use. This 2007 model is perfect for both hobbyists and professionals seeking a reliable machine that delivers performance without breaking the bank. With its striking blue exterior and standard interior, it combines functionality with a touch of style. Experience the benefits of modern engineering with this budget-friendly cultivator.',
#    'full_text_boosted': 'Machine Cultivator Ezee-On 5537-56-13-10 2007 Diesel I4 2.2L Automatic 4WD Diesel Blue Standard Standard Adjustable tines User-friendly controls Compact design Stability control Reinforced structure'},
#   'completion_terms': [{'tag': 'Machine'},
#    {'tag': 'Cultivator'},
#    {'tag': 'Ezee-On'},
#    {'tag': '5537-56-13-10'},
#    {'tag': '2007'},
#    {'tag': 'Diesel'},
#    {'tag': 'I4 2.2L'},
#    {'tag': 'Automatic'},
#    {'tag': '4WD'},
#    {'tag': 'Diesel'},
#    {'tag': 'Blue'},
#    {'tag': 'Standard'},
#    {'tag': 'Standard'},
#    {'tag': 'Adjustable tines'},
#    {'tag': 'User-friendly controls'},
#    {'tag': 'Compact design'},
#    {'tag': 'Stability control'},
#    {'tag': 'Reinforced structure'}],
#   'suggestion_terms': ['Machine',
#    'Cultivator',
#    'Ezee-On',
#    '5537-56-13-10',
#    '2007',
#    'Diesel',
#    'I4 2.2L',
#    'Automatic',
#    '4WD',
#    'Diesel',
#    'Blue',
#    'Standard',
#    'Standard',
#    'Adjustable tines',
#    'User-friendly controls',
#    'Compact design',
#    'Stability control',
#    'Reinforced structure'],
#   'id': 'bd378942-8af9-4bb2-a404-676ef71cd5d7'},
#  {'termFacetData': [{'name': 'year', 'value': '2018'},
#    {'name': 'engine_type', 'value': 'Diesel'},
#    {'name': 'engine_size', 'value': 'V12 18.1L'},
#    {'name': 'transmission', 'value': 'Automatic'},
#    {'name': 'drive_type', 'value': '4WD'},
#    {'name': 'fuel_type', 'value': 'Diesel'},
#    {'name': 'exterior_color', 'value': 'Red'},
#    {'name': 'interior_color', 'value': 'Standard'},
#    {'name': 'trim_level', 'value': 'Standard'},
#    {'name': 'notable_features',
#     'value': ['Hydraulic controls',
#      'High-capacity bucket',
#      'Heavy-duty tracks']},
#    {'name': 'safety_features',
#     'value': ['ABS', 'Reinforced structure', 'Stability control']}],
#   'numberFacetData': [{'name': 'price', 'value': '3200'}],
#   'pathFacetData': [[{'id': None,
#      'name': 'type',
#      'value': 'Type',
#      'type': 'root'},
#     {'id': None, 'name': 'type', 'value': 'Type/Machine', 'type': 'type'},
#     {'id': None,
#      'name': 'type',
#      'value': 'Type/Machine/Shovel',
#      'type': 'category'}],
#    [{'id': None, 'name': 'brand', 'value': 'Brand', 'type': 'root'},
#     {'id': None,
#      'name': 'brand',
#      'value': 'Brand/Caterpillar',
#      'type': 'brand'},
#     {'id': None,
#      'name': 'brand',
#      'value': 'Brand/Caterpillar/6060 AC/6060 AC FS',
#      'type': 'model'}]],
#   'search_data': {'full_text': "Discover the power and reliability of the Caterpillar 6060 AC/6060 AC FS, a robust machine designed for heavy-duty tasks. This 2018 model comes in a striking red exterior, ensuring you stand out on the job site. With its budget-friendly operation and impressive performance, this shovel is perfect for those looking to enhance their fleet without breaking the bank. Equipped with standard features and a focus on safety, it's ready to tackle your toughest projects.",
#    'full_text_boosted': 'Machine Shovel Caterpillar 6060 AC/6060 AC FS 2018 Diesel V12 18.1L Automatic 4WD Diesel Red Standard Standard Hydraulic controls High-capacity bucket Heavy-duty tracks ABS Reinforced structure Stability control'},
#   'completion_terms': [{'tag': 'Machine'},
#    {'tag': 'Shovel'},
#    {'tag': 'Caterpillar'},
#    {'tag': '6060 AC/6060 AC FS'},
#    {'tag': '2018'},
#    {'tag': 'Diesel'},
#    {'tag': 'V12 18.1L'},
#    {'tag': 'Automatic'},
#    {'tag': '4WD'},
#    {'tag': 'Diesel'},
#    {'tag': 'Red'},
#    {'tag': 'Standard'},
#    {'tag': 'Standard'},
#    {'tag': 'Hydraulic controls'},
#    {'tag': 'High-capacity bucket'},
#    {'tag': 'Heavy-duty tracks'},
#    {'tag': 'ABS'},
#    {'tag': 'Reinforced structure'},
#    {'tag': 'Stability control'}],
#   'suggestion_terms': ['Machine',
#    'Shovel',
#    'Caterpillar',
#    '6060 AC/6060 AC FS',
#    '2018',
#    'Diesel',
#    'V12 18.1L',
#    'Automatic',
#    '4WD',
#    'Diesel',
#    'Red',
#    'Standard',
#    'Standard',
#    'Hydraulic controls',
#    'High-capacity bucket',
#    'Heavy-duty tracks',
#    'ABS',
#    'Reinforced structure',
#    'Stability control'],
#   'id': 'f45b020e-9c63-45fc-a563-5ccd93388297'},
#  {'termFacetData': [{'name': 'year', 'value': '1999'},
#    {'name': 'engine_type', 'value': 'I4'},
#    {'name': 'engine_size', 'value': '1.8L'},
#    {'name': 'transmission', 'value': 'Automatic'},
#    {'name': 'drive_type', 'value': 'FWD'},
#    {'name': 'fuel_type', 'value': 'Gasoline'},
#    {'name': 'exterior_color', 'value': 'Green'},
#    {'name': 'interior_color', 'value': 'Standard'},
#    {'name': 'trim_level', 'value': 'Standard'},
#    {'name': 'notable_features',
#     'value': ['Leather seats', 'Sunroof', 'Power windows']},
#    {'name': 'safety_features',
#     'value': ['ABS', 'Airbags', 'Traction control']}],
#   'numberFacetData': [{'name': 'price', 'value': '2500'}],
#   'pathFacetData': [[{'id': None,
#      'name': 'type',
#      'value': 'Type',
#      'type': 'root'},
#     {'id': None, 'name': 'type', 'value': 'Type/Vehicle', 'type': 'type'},
#     {'id': None,
#      'name': 'type',
#      'value': 'Type/Vehicle/Sedan, Wagon',
#      'type': 'category'}],
#    [{'id': None, 'name': 'brand', 'value': 'Brand', 'type': 'root'},
#     {'id': None, 'name': 'brand', 'value': 'Brand/Audi', 'type': 'brand'},
#     {'id': None, 'name': 'brand', 'value': 'Brand/Audi/A4', 'type': 'model'}]],
#   'search_data': {'full_text': 'Experience the charm of the classic Audi A4, a budget-friendly sedan that combines German engineering with a touch of elegance. This 1999 model boasts a striking green exterior and a comfortable standard interior, making it a perfect choice for both daily commutes and weekend getaways. With its reliable performance and practical features, this vehicle is designed for those who appreciate quality without breaking the bank.',
#    'full_text_boosted': 'Vehicle Sedan, Wagon Audi A4 1999 I4 1.8L Automatic FWD Gasoline Green Standard Standard Leather seats Sunroof Power windows ABS Airbags Traction control'},
#   'completion_terms': [{'tag': 'Vehicle'},
#    {'tag': 'Sedan, Wagon'},
#    {'tag': 'Audi'},
#    {'tag': 'A4'},
#    {'tag': '1999'},
#    {'tag': 'I4'},
#    {'tag': '1.8L'},
#    {'tag': 'Automatic'},
#    {'tag': 'FWD'},
#    {'tag': 'Gasoline'},
#    {'tag': 'Green'},
#    {'tag': 'Standard'},
#    {'tag': 'Standard'},
#    {'tag': 'Leather seats'},
#    {'tag': 'Sunroof'},
#    {'tag': 'Power windows'},
#    {'tag': 'ABS'},
#    {'tag': 'Airbags'},
#    {'tag': 'Traction control'}],
#   'suggestion_terms': ['Vehicle',
#    'Sedan, Wagon',
#    'Audi',
#    'A4',
#    '1999',
#    'I4',
#    '1.8L',
#    'Automatic',
#    'FWD',
#    'Gasoline',
#    'Green',
#    'Standard',
#    'Standard',
#    'Leather seats',
#    'Sunroof',
#    'Power windows',
#    'ABS',
#    'Airbags',
#    'Traction control'],
#   'id': '7b99e3e7-d64e-4f99-ab28-5b9b1b886524'},
#  {'termFacetData': [{'name': 'year', 'value': '2019'},
#    {'name': 'engine_type', 'value': 'Diesel'},
#    {'name': 'engine_size', 'value': '4.5L'},
#    {'name': 'transmission', 'value': 'Automatic'},
#    {'name': 'drive_type', 'value': '4WD'},
#    {'name': 'fuel_type', 'value': 'Diesel'},
#    {'name': 'exterior_color', 'value': 'Black'},
#    {'name': 'interior_color', 'value': 'Standard'},
#    {'name': 'trim_level', 'value': 'Standard'},
#    {'name': 'notable_features',
#     'value': ['Hydraulic system', 'Adjustable tracks', 'Rearview camera']},
#    {'name': 'safety_features',
#     'value': ['Stability control', 'Reinforced structure', 'Emergency stop']}],
#   'numberFacetData': [{'name': 'price', 'value': '2200'}],
#   'pathFacetData': [[{'id': None,
#      'name': 'type',
#      'value': 'Type',
#      'type': 'root'},
#     {'id': None, 'name': 'type', 'value': 'Type/Machine', 'type': 'type'},
#     {'id': None,
#      'name': 'type',
#      'value': 'Type/Machine/Crawler Tractor',
#      'type': 'category'}],
#    [{'id': None, 'name': 'brand', 'value': 'Brand', 'type': 'root'},
#     {'id': None,
#      'name': 'brand',
#      'value': 'Brand/John Deere',
#      'type': 'brand'},
#     {'id': None,
#      'name': 'brand',
#      'value': 'Brand/John Deere/550H LGP',
#      'type': 'model'}]],
#   'search_data': {'full_text': 'Discover the power and reliability of the John Deere 550H LGP, a robust crawler tractor designed for heavy-duty tasks. This budget-friendly machine features a durable black exterior and a standard interior, making it perfect for both professional and personal projects. With its impressive performance and dependable build, this tractor is ready to tackle any challenge you throw at it.',
#    'full_text_boosted': 'Machine Crawler Tractor John Deere 550H LGP 2019 Diesel 4.5L Automatic 4WD Diesel Black Standard Standard Hydraulic system Adjustable tracks Rearview camera Stability control Reinforced structure Emergency stop'},
#   'completion_terms': [{'tag': 'Machine'},
#    {'tag': 'Crawler Tractor'},
#    {'tag': 'John Deere'},
#    {'tag': '550H LGP'},
#    {'tag': '2019'},
#    {'tag': 'Diesel'},
#    {'tag': '4.5L'},
#    {'tag': 'Automatic'},
#    {'tag': '4WD'},
#    {'tag': 'Diesel'},
#    {'tag': 'Black'},
#    {'tag': 'Standard'},
#    {'tag': 'Standard'},
#    {'tag': 'Hydraulic system'},
#    {'tag': 'Adjustable tracks'},
#    {'tag': 'Rearview camera'},
#    {'tag': 'Stability control'},
#    {'tag': 'Reinforced structure'},
#    {'tag': 'Emergency stop'}],
#   'suggestion_terms': ['Machine',
#    'Crawler Tractor',
#    'John Deere',
#    '550H LGP',
#    '2019',
#    'Diesel',
#    '4.5L',
#    'Automatic',
#    '4WD',
#    'Diesel',
#    'Black',
#    'Standard',
#    'Standard',
#    'Hydraulic system',
#    'Adjustable tracks',
#    'Rearview camera',
#    'Stability control',
#    'Reinforced structure',
#    'Emergency stop'],
#   'id': '94dcf74c-f2e6-4e81-8e1e-2670c5c5b9c3'},
#  {'termFacetData': [{'name': 'year', 'value': '1997'},
#    {'name': 'engine_type', 'value': 'V6'},
#    {'name': 'engine_size', 'value': '3.0L'},
#    {'name': 'transmission', 'value': 'Automatic'},
#    {'name': 'drive_type', 'value': 'FWD'},
#    {'name': 'fuel_type', 'value': 'Gasoline'},
#    {'name': 'exterior_color', 'value': 'Blue'},
#    {'name': 'interior_color', 'value': 'Standard'},
#    {'name': 'trim_level', 'value': 'Standard'},
#    {'name': 'notable_features',
#     'value': ['Spacious interior', 'Air conditioning', 'AM/FM radio']},
#    {'name': 'safety_features', 'value': ['ABS', 'Airbags']}],
#   'numberFacetData': [{'name': 'price', 'value': '7300'}],
#   'pathFacetData': [[{'id': None,
#      'name': 'type',
#      'value': 'Type',
#      'type': 'root'},
#     {'id': None, 'name': 'type', 'value': 'Type/Vehicle', 'type': 'type'},
#     {'id': None,
#      'name': 'type',
#      'value': 'Type/Vehicle/Van/Minivan',
#      'type': 'category'}],
#    [{'id': None, 'name': 'brand', 'value': 'Brand', 'type': 'root'},
#     {'id': None, 'name': 'brand', 'value': 'Brand/Nissan', 'type': 'brand'},
#     {'id': None,
#      'name': 'brand',
#      'value': 'Brand/Nissan/Quest',
#      'type': 'model'}]],
#   'search_data': {'full_text': 'Discover the charm of the 1997 Nissan Quest, a budget-friendly minivan that offers spaciousness and reliability for families on the go. With its blue exterior and standard interior, this vehicle combines practicality with comfort, making it a perfect choice for daily errands or weekend getaways. Experience the ease of driving with its smooth handling and ample storage space, ensuring every trip is enjoyable.',
#    'full_text_boosted': 'Vehicle Van/Minivan Nissan Quest 1997 V6 3.0L Automatic FWD Gasoline Blue Standard Standard Spacious interior Air conditioning AM/FM radio ABS Airbags'},
#   'completion_terms': [{'tag': 'Vehicle'},
#    {'tag': 'Van/Minivan'},
#    {'tag': 'Nissan'},
#    {'tag': 'Quest'},
#    {'tag': '1997'},
#    {'tag': 'V6'},
#    {'tag': '3.0L'},
#    {'tag': 'Automatic'},
#    {'tag': 'FWD'},
#    {'tag': 'Gasoline'},
#    {'tag': 'Blue'},
#    {'tag': 'Standard'},
#    {'tag': 'Standard'},
#    {'tag': 'Spacious interior'},
#    {'tag': 'Air conditioning'},
#    {'tag': 'AM/FM radio'},
#    {'tag': 'ABS'},
#    {'tag': 'Airbags'}],
#   'suggestion_terms': ['Vehicle',
#    'Van/Minivan',
#    'Nissan',
#    'Quest',
#    '1997',
#    'V6',
#    '3.0L',
#    'Automatic',
#    'FWD',
#    'Gasoline',
#    'Blue',
#    'Standard',
#    'Standard',
#    'Spacious interior',
#    'Air conditioning',
#    'AM/FM radio',
#    'ABS',
#    'Airbags'],
#   'id': '7c8785d1-0a34-470f-8d29-bf741b1d7669'},
#  {'termFacetData': [{'name': 'year', 'value': '2019'},
#    {'name': 'engine_type', 'value': 'I4'},
#    {'name': 'engine_size', 'value': '1.4L'},
#    {'name': 'transmission', 'value': 'Automatic'},
#    {'name': 'drive_type', 'value': 'FWD'},
#    {'name': 'fuel_type', 'value': 'Gasoline'},
#    {'name': 'exterior_color', 'value': 'Red'},
#    {'name': 'interior_color', 'value': 'Standard'},
#    {'name': 'trim_level', 'value': 'Standard'},
#    {'name': 'notable_features',
#     'value': ['Bluetooth', 'Backup camera', 'Cruise control']},
#    {'name': 'safety_features',
#     'value': ['ABS', 'Airbags', 'Stability control']}],
#   'numberFacetData': [{'name': 'price', 'value': '8600'}],
#   'pathFacetData': [[{'id': None,
#      'name': 'type',
#      'value': 'Type',
#      'type': 'root'},
#     {'id': None, 'name': 'type', 'value': 'Type/Vehicle', 'type': 'type'},
#     {'id': None,
#      'name': 'type',
#      'value': 'Type/Vehicle/Sedan, Hatchback',
#      'type': 'category'}],
#    [{'id': None, 'name': 'brand', 'value': 'Brand', 'type': 'root'},
#     {'id': None, 'name': 'brand', 'value': 'Brand/Chevrolet', 'type': 'brand'},
#     {'id': None,
#      'name': 'brand',
#      'value': 'Brand/Chevrolet/Sonic',
#      'type': 'model'}]],
#   'search_data': {'full_text': "Experience the perfect blend of style and efficiency with this 2019 Chevrolet Sonic. This compact sedan is designed for urban adventures, offering a budget-friendly option without compromising on comfort. With its vibrant red exterior and standard interior, it's both eye-catching and practical. Enjoy features like Bluetooth connectivity and a backup camera, making every drive enjoyable and safe.",
#    'full_text_boosted': 'Vehicle Sedan, Hatchback Chevrolet Sonic 2019 I4 1.4L Automatic FWD Gasoline Red Standard Standard Bluetooth Backup camera Cruise control ABS Airbags Stability control'},
#   'completion_terms': [{'tag': 'Vehicle'},
#    {'tag': 'Sedan, Hatchback'},
#    {'tag': 'Chevrolet'},
#    {'tag': 'Sonic'},
#    {'tag': '2019'},
#    {'tag': 'I4'},
#    {'tag': '1.4L'},
#    {'tag': 'Automatic'},
#    {'tag': 'FWD'},
#    {'tag': 'Gasoline'},
#    {'tag': 'Red'},
#    {'tag': 'Standard'},
#    {'tag': 'Standard'},
#    {'tag': 'Bluetooth'},
#    {'tag': 'Backup camera'},
#    {'tag': 'Cruise control'},
#    {'tag': 'ABS'},
#    {'tag': 'Airbags'},
#    {'tag': 'Stability control'}],
#   'suggestion_terms': ['Vehicle',
#    'Sedan, Hatchback',
#    'Chevrolet',
#    'Sonic',
#    '2019',
#    'I4',
#    '1.4L',
#    'Automatic',
#    'FWD',
#    'Gasoline',
#    'Red',
#    'Standard',
#    'Standard',
#    'Bluetooth',
#    'Backup camera',
#    'Cruise control',
#    'ABS',
#    'Airbags',
#    'Stability control'],
#   'id': '510ed265-2cd2-4d8a-ba03-f86536cd5312'},
#  {'termFacetData': [{'name': 'year', 'value': '2008'},
#    {'name': 'engine_type', 'value': 'Diesel'},
#    {'name': 'engine_size', 'value': '4.5L'},
#    {'name': 'transmission', 'value': 'Automatic'},
#    {'name': 'drive_type', 'value': '4WD'},
#    {'name': 'fuel_type', 'value': 'Diesel'},
#    {'name': 'exterior_color', 'value': 'Blue'},
#    {'name': 'interior_color', 'value': 'Standard'},
#    {'name': 'trim_level', 'value': 'Standard'},
#    {'name': 'notable_features',
#     'value': ['Hydraulic lift', 'Vibratory system', "Operator's cabin"]},
#    {'name': 'safety_features',
#     'value': ['Stability control', 'Reinforced structure', 'Emergency stop']}],
#   'numberFacetData': [{'name': 'price', 'value': '3300'}],
#   'pathFacetData': [[{'id': None,
#      'name': 'type',
#      'value': 'Type',
#      'type': 'root'},
#     {'id': None, 'name': 'type', 'value': 'Type/Machine', 'type': 'type'},
#     {'id': None,
#      'name': 'type',
#      'value': 'Type/Machine/Vibratory Smooth Drum Roller',
#      'type': 'category'}],
#    [{'id': None, 'name': 'brand', 'value': 'Brand', 'type': 'root'},
#     {'id': None, 'name': 'brand', 'value': 'Brand/LiuGong', 'type': 'brand'},
#     {'id': None,
#      'name': 'brand',
#      'value': 'Brand/LiuGong/612H',
#      'type': 'model'}]],
#   'search_data': {'full_text': 'Discover the LiuGong 612H, a robust and reliable vibratory smooth drum roller from 2008. This machine is designed for efficiency and performance, making it an excellent choice for your construction needs. With its durable blue exterior and standard interior, it offers a practical solution for any job site. The LiuGong 612H is budget-friendly, ensuring you get the job done without breaking the bank.',
#    'full_text_boosted': "Machine Vibratory Smooth Drum Roller LiuGong 612H 2008 Diesel 4.5L Automatic 4WD Diesel Blue Standard Standard Hydraulic lift Vibratory system Operator's cabin Stability control Reinforced structure Emergency stop"},
#   'completion_terms': [{'tag': 'Machine'},
#    {'tag': 'Vibratory Smooth Drum Roller'},
#    {'tag': 'LiuGong'},
#    {'tag': '612H'},
#    {'tag': '2008'},
#    {'tag': 'Diesel'},
#    {'tag': '4.5L'},
#    {'tag': 'Automatic'},
#    {'tag': '4WD'},
#    {'tag': 'Diesel'},
#    {'tag': 'Blue'},
#    {'tag': 'Standard'},
#    {'tag': 'Standard'},
#    {'tag': 'Hydraulic lift'},
#    {'tag': 'Vibratory system'},
#    {'tag': "Operator's cabin"},
#    {'tag': 'Stability control'},
#    {'tag': 'Reinforced structure'},
#    {'tag': 'Emergency stop'}],
#   'suggestion_terms': ['Machine',
#    'Vibratory Smooth Drum Roller',
#    'LiuGong',
#    '612H',
#    '2008',
#    'Diesel',
#    '4.5L',
#    'Automatic',
#    '4WD',
#    'Diesel',
#    'Blue',
#    'Standard',
#    'Standard',
#    'Hydraulic lift',
#    'Vibratory system',
#    "Operator's cabin",
#    'Stability control',
#    'Reinforced structure',
#    'Emergency stop'],
#   'id': '14f6b6c6-952a-4b72-933a-ed3492735269'},
#  {'termFacetData': [{'name': 'year', 'value': '2019'},
#    {'name': 'engine_type', 'value': 'Diesel'},
#    {'name': 'engine_size', 'value': 'C6.6 6.6L'},
#    {'name': 'transmission', 'value': 'Automatic'},
#    {'name': 'drive_type', 'value': '4WD'},
#    {'name': 'fuel_type', 'value': 'Diesel'},
#    {'name': 'exterior_color', 'value': 'Green'},
#    {'name': 'interior_color', 'value': 'Standard'},
#    {'name': 'trim_level', 'value': 'Standard'},
#    {'name': 'notable_features',
#     'value': ['Hydraulic blade', 'GPS guidance', 'Reinforced structure']},
#    {'name': 'safety_features',
#     'value': ['Stability control', 'Rollover protection', 'Emergency stop']}],
#   'numberFacetData': [{'name': 'price', 'value': '1600'}],
#   'pathFacetData': [[{'id': None,
#      'name': 'type',
#      'value': 'Type',
#      'type': 'root'},
#     {'id': None, 'name': 'type', 'value': 'Type/Machine', 'type': 'type'},
#     {'id': None,
#      'name': 'type',
#      'value': 'Type/Machine/Crawler Tractor',
#      'type': 'category'}],
#    [{'id': None, 'name': 'brand', 'value': 'Brand', 'type': 'root'},
#     {'id': None,
#      'name': 'brand',
#      'value': 'Brand/Caterpillar',
#      'type': 'brand'},
#     {'id': None,
#      'name': 'brand',
#      'value': 'Brand/Caterpillar/D6T XL VPAT',
#      'type': 'model'}]],
#   'search_data': {'full_text': 'Experience the power and reliability of the 2019 Caterpillar D6T XL VPAT, a premium crawler tractor designed for heavy-duty tasks. Its robust construction and advanced features make it a perfect choice for both professionals and enthusiasts seeking efficiency and durability in their projects.',
#    'full_text_boosted': 'Machine Crawler Tractor Caterpillar D6T XL VPAT 2019 Diesel C6.6 6.6L Automatic 4WD Diesel Green Standard Standard Hydraulic blade GPS guidance Reinforced structure Stability control Rollover protection Emergency stop'},
#   'completion_terms': [{'tag': 'Machine'},
#    {'tag': 'Crawler Tractor'},
#    {'tag': 'Caterpillar'},
#    {'tag': 'D6T XL VPAT'},
#    {'tag': '2019'},
#    {'tag': 'Diesel'},
#    {'tag': 'C6.6 6.6L'},
#    {'tag': 'Automatic'},
#    {'tag': '4WD'},
#    {'tag': 'Diesel'},
#    {'tag': 'Green'},
#    {'tag': 'Standard'},
#    {'tag': 'Standard'},
#    {'tag': 'Hydraulic blade'},
#    {'tag': 'GPS guidance'},
#    {'tag': 'Reinforced structure'},
#    {'tag': 'Stability control'},
#    {'tag': 'Rollover protection'},
#    {'tag': 'Emergency stop'}],
#   'suggestion_terms': ['Machine',
#    'Crawler Tractor',
#    'Caterpillar',
#    'D6T XL VPAT',
#    '2019',
#    'Diesel',
#    'C6.6 6.6L',
#    'Automatic',
#    '4WD',
#    'Diesel',
#    'Green',
#    'Standard',
#    'Standard',
#    'Hydraulic blade',
#    'GPS guidance',
#    'Reinforced structure',
#    'Stability control',
#    'Rollover protection',
#    'Emergency stop'],
#   'id': 'd0b241c0-44b4-4b07-a6d0-cfe97d58ea3a'},
#  {'termFacetData': [{'name': 'year', 'value': '1992'},
#    {'name': 'engine_type', 'value': 'V6'},
#    {'name': 'engine_size', 'value': '3.0L'},
#    {'name': 'transmission', 'value': 'Automatic'},
#    {'name': 'drive_type', 'value': 'RWD'},
#    {'name': 'fuel_type', 'value': 'Gasoline'},
#    {'name': 'exterior_color', 'value': 'Black'},
#    {'name': 'interior_color', 'value': 'Standard'},
#    {'name': 'trim_level', 'value': 'Standard'},
#    {'name': 'notable_features',
#     'value': ['Leather seats', 'Sunroof', 'Cruise control']},
#    {'name': 'safety_features',
#     'value': ['ABS', 'Airbags', 'Traction control']}],
#   'numberFacetData': [{'name': 'price', 'value': '1700'}],
#   'pathFacetData': [[{'id': None,
#      'name': 'type',
#      'value': 'Type',
#      'type': 'root'},
#     {'id': None, 'name': 'type', 'value': 'Type/Vehicle', 'type': 'type'},
#     {'id': None,
#      'name': 'type',
#      'value': 'Type/Vehicle/Sedan',
#      'type': 'category'}],
#    [{'id': None, 'name': 'brand', 'value': 'Brand', 'type': 'root'},
#     {'id': None, 'name': 'brand', 'value': 'Brand/INFINITI', 'type': 'brand'},
#     {'id': None,
#      'name': 'brand',
#      'value': 'Brand/INFINITI/G',
#      'type': 'model'}]],
#   'search_data': {'full_text': 'Experience a classic blend of luxury and performance with this 1992 INFINITI G sedan. Its sleek black exterior and comfortable interior make it a stylish choice for those seeking an affordable yet sophisticated ride. With its reliable engineering and smooth handling, this vehicle is perfect for daily commutes or weekend getaways.',
#    'full_text_boosted': 'Vehicle Sedan INFINITI G 1992 V6 3.0L Automatic RWD Gasoline Black Standard Standard Leather seats Sunroof Cruise control ABS Airbags Traction control'},
#   'completion_terms': [{'tag': 'Vehicle'},
#    {'tag': 'Sedan'},
#    {'tag': 'INFINITI'},
#    {'tag': 'G'},
#    {'tag': '1992'},
#    {'tag': 'V6'},
#    {'tag': '3.0L'},
#    {'tag': 'Automatic'},
#    {'tag': 'RWD'},
#    {'tag': 'Gasoline'},
#    {'tag': 'Black'},
#    {'tag': 'Standard'},
#    {'tag': 'Standard'},
#    {'tag': 'Leather seats'},
#    {'tag': 'Sunroof'},
#    {'tag': 'Cruise control'},
#    {'tag': 'ABS'},
#    {'tag': 'Airbags'},
#    {'tag': 'Traction control'}],
#   'suggestion_terms': ['Vehicle',
#    'Sedan',
#    'INFINITI',
#    'G',
#    '1992',
#    'V6',
#    '3.0L',
#    'Automatic',
#    'RWD',
#    'Gasoline',
#    'Black',
#    'Standard',
#    'Standard',
#    'Leather seats',
#    'Sunroof',
#    'Cruise control',
#    'ABS',
#    'Airbags',
#    'Traction control'],
#   'id': '03a2b109-4ef4-4e30-ab60-3e8757428447'},
#  {'termFacetData': [{'name': 'year', 'value': '2004'},
#    {'name': 'engine_type', 'value': 'I4'},
#    {'name': 'engine_size', 'value': '1.8L'},
#    {'name': 'transmission', 'value': 'Manual'},
#    {'name': 'drive_type', 'value': 'RWD'},
#    {'name': 'fuel_type', 'value': 'Gasoline'},
#    {'name': 'exterior_color', 'value': 'White'},
#    {'name': 'interior_color', 'value': 'Standard'},
#    {'name': 'trim_level', 'value': 'Standard'},
#    {'name': 'notable_features',
#     'value': ['Leather seats', 'Bluetooth', 'Manual transmission']},
#    {'name': 'safety_features',
#     'value': ['ABS', 'Airbags', 'Stability control']}],
#   'numberFacetData': [{'name': 'price', 'value': '4500'}],
#   'pathFacetData': [[{'id': None,
#      'name': 'type',
#      'value': 'Type',
#      'type': 'root'},
#     {'id': None, 'name': 'type', 'value': 'Type/Vehicle', 'type': 'type'},
#     {'id': None,
#      'name': 'type',
#      'value': 'Type/Vehicle/Convertible',
#      'type': 'category'}],
#    [{'id': None, 'name': 'brand', 'value': 'Brand', 'type': 'root'},
#     {'id': None, 'name': 'brand', 'value': 'Brand/MAZDA', 'type': 'brand'},
#     {'id': None,
#      'name': 'brand',
#      'value': 'Brand/MAZDA/MX-5 Miata',
#      'type': 'model'}]],
#   'search_data': {'full_text': 'Experience the thrill of open-air driving with this charming 2004 MAZDA MX-5 Miata. This budget-friendly convertible offers a spirited performance and agile handling, making it a joy to drive on winding roads. With its sleek white exterior and standard interior, this classic roadster is perfect for those seeking a fun and stylish ride.',
#    'full_text_boosted': 'Vehicle Convertible MAZDA MX-5 Miata 2004 I4 1.8L Manual RWD Gasoline White Standard Standard Leather seats Bluetooth Manual transmission ABS Airbags Stability control'},
#   'completion_terms': [{'tag': 'Vehicle'},
#    {'tag': 'Convertible'},
#    {'tag': 'MAZDA'},
#    {'tag': 'MX-5 Miata'},
#    {'tag': '2004'},
#    {'tag': 'I4'},
#    {'tag': '1.8L'},
#    {'tag': 'Manual'},
#    {'tag': 'RWD'},
#    {'tag': 'Gasoline'},
#    {'tag': 'White'},
#    {'tag': 'Standard'},
#    {'tag': 'Standard'},
#    {'tag': 'Leather seats'},
#    {'tag': 'Bluetooth'},
#    {'tag': 'Manual transmission'},
#    {'tag': 'ABS'},
#    {'tag': 'Airbags'},
#    {'tag': 'Stability control'}],
#   'suggestion_terms': ['Vehicle',
#    'Convertible',
#    'MAZDA',
#    'MX-5 Miata',
#    '2004',
#    'I4',
#    '1.8L',
#    'Manual',
#    'RWD',
#    'Gasoline',
#    'White',
#    'Standard',
#    'Standard',
#    'Leather seats',
#    'Bluetooth',
#    'Manual transmission',
#    'ABS',
#    'Airbags',
#    'Stability control'],
#   'id': 'ba2a3a7d-58c5-4d4b-8207-c39dc68e460a'},
#  {'termFacetData': [{'name': 'year', 'value': '1994'},
#    {'name': 'engine_type', 'value': 'I4'},
#    {'name': 'engine_size', 'value': '1.8L'},
#    {'name': 'transmission', 'value': 'Automatic'},
#    {'name': 'drive_type', 'value': 'FWD'},
#    {'name': 'fuel_type', 'value': 'Gasoline'},
#    {'name': 'exterior_color', 'value': 'Blue'},
#    {'name': 'interior_color', 'value': 'Standard'},
#    {'name': 'trim_level', 'value': 'Standard'},
#    {'name': 'notable_features',
#     'value': ['Air Conditioning', 'AM/FM Radio', 'Power Windows']},
#    {'name': 'safety_features', 'value': ['ABS', 'Airbags']}],
#   'numberFacetData': [{'name': 'price', 'value': '8900'}],
#   'pathFacetData': [[{'id': None,
#      'name': 'type',
#      'value': 'Type',
#      'type': 'root'},
#     {'id': None, 'name': 'type', 'value': 'Type/Vehicle', 'type': 'type'},
#     {'id': None,
#      'name': 'type',
#      'value': 'Type/Vehicle/Sedan',
#      'type': 'category'}],
#    [{'id': None, 'name': 'brand', 'value': 'Brand', 'type': 'root'},
#     {'id': None, 'name': 'brand', 'value': 'Brand/Plymouth', 'type': 'brand'},
#     {'id': None,
#      'name': 'brand',
#      'value': 'Brand/Plymouth/Colt',
#      'type': 'model'}]],
#   'search_data': {'full_text': 'Experience the charm of the classic 1994 Plymouth Colt, a budget-friendly sedan that combines reliability with a touch of nostalgia. This compact vehicle is perfect for city driving, offering easy maneuverability and a comfortable ride. Its vibrant blue exterior is sure to turn heads, while the standard interior provides all the essentials for a pleasant journey.',
#    'full_text_boosted': 'Vehicle Sedan Plymouth Colt 1994 I4 1.8L Automatic FWD Gasoline Blue Standard Standard Air Conditioning AM/FM Radio Power Windows ABS Airbags'},
#   'completion_terms': [{'tag': 'Vehicle'},
#    {'tag': 'Sedan'},
#    {'tag': 'Plymouth'},
#    {'tag': 'Colt'},
#    {'tag': '1994'},
#    {'tag': 'I4'},
#    {'tag': '1.8L'},
#    {'tag': 'Automatic'},
#    {'tag': 'FWD'},
#    {'tag': 'Gasoline'},
#    {'tag': 'Blue'},
#    {'tag': 'Standard'},
#    {'tag': 'Standard'},
#    {'tag': 'Air Conditioning'},
#    {'tag': 'AM/FM Radio'},
#    {'tag': 'Power Windows'},
#    {'tag': 'ABS'},
#    {'tag': 'Airbags'}],
#   'suggestion_terms': ['Vehicle',
#    'Sedan',
#    'Plymouth',
#    'Colt',
#    '1994',
#    'I4',
#    '1.8L',
#    'Automatic',
#    'FWD',
#    'Gasoline',
#    'Blue',
#    'Standard',
#    'Standard',
#    'Air Conditioning',
#    'AM/FM Radio',
#    'Power Windows',
#    'ABS',
#    'Airbags'],
#   'id': '49f486a0-8bb5-4761-bfb0-b1cd3043d03b'},
#  {'termFacetData': [{'name': 'year', 'value': '2001'},
#    {'name': 'engine_type', 'value': 'I4'},
#    {'name': 'engine_size', 'value': '2.0L'},
#    {'name': 'transmission', 'value': 'Automatic'},
#    {'name': 'drive_type', 'value': 'FWD'},
#    {'name': 'fuel_type', 'value': 'Gasoline'},
#    {'name': 'exterior_color', 'value': 'Blue'},
#    {'name': 'interior_color', 'value': 'Standard'},
#    {'name': 'trim_level', 'value': 'Standard'},
#    {'name': 'notable_features',
#     'value': ['Leather seats', 'Sunroof', 'CD player']},
#    {'name': 'safety_features',
#     'value': ['ABS', 'Airbags', 'Traction control']}],
#   'numberFacetData': [{'name': 'price', 'value': '9300'}],
#   'pathFacetData': [[{'id': None,
#      'name': 'type',
#      'value': 'Type',
#      'type': 'root'},
#     {'id': None, 'name': 'type', 'value': 'Type/Vehicle', 'type': 'type'},
#     {'id': None,
#      'name': 'type',
#      'value': 'Type/Vehicle/Wagon',
#      'type': 'category'}],
#    [{'id': None, 'name': 'brand', 'value': 'Brand', 'type': 'root'},
#     {'id': None, 'name': 'brand', 'value': 'Brand/Volvo', 'type': 'brand'},
#     {'id': None,
#      'name': 'brand',
#      'value': 'Brand/Volvo/V40',
#      'type': 'model'}]],
#   'search_data': {'full_text': 'Experience the charm of a classic with the 2001 Volvo V40. This budget-friendly wagon combines practicality with a touch of Scandinavian style. With its spacious interior and solid build, it’s perfect for family outings or daily commutes. Enjoy the reliability and comfort that Volvo is known for, making every drive a pleasure.',
#    'full_text_boosted': 'Vehicle Wagon Volvo V40 2001 I4 2.0L Automatic FWD Gasoline Blue Standard Standard Leather seats Sunroof CD player ABS Airbags Traction control'},
#   'completion_terms': [{'tag': 'Vehicle'},
#    {'tag': 'Wagon'},
#    {'tag': 'Volvo'},
#    {'tag': 'V40'},
#    {'tag': '2001'},
#    {'tag': 'I4'},
#    {'tag': '2.0L'},
#    {'tag': 'Automatic'},
#    {'tag': 'FWD'},
#    {'tag': 'Gasoline'},
#    {'tag': 'Blue'},
#    {'tag': 'Standard'},
#    {'tag': 'Standard'},
#    {'tag': 'Leather seats'},
#    {'tag': 'Sunroof'},
#    {'tag': 'CD player'},
#    {'tag': 'ABS'},
#    {'tag': 'Airbags'},
#    {'tag': 'Traction control'}],
#   'suggestion_terms': ['Vehicle',
#    'Wagon',
#    'Volvo',
#    'V40',
#    '2001',
#    'I4',
#    '2.0L',
#    'Automatic',
#    'FWD',
#    'Gasoline',
#    'Blue',
#    'Standard',
#    'Standard',
#    'Leather seats',
#    'Sunroof',
#    'CD player',
#    'ABS',
#    'Airbags',
#    'Traction control'],
#   'id': 'dd1d8ec8-6836-49b1-9122-ed1fb5e92ad6'},
#  {'termFacetData': [{'name': 'year', 'value': '2003'},
#    {'name': 'engine_type', 'value': 'I4'},
#    {'name': 'engine_size', 'value': '2.0L'},
#    {'name': 'transmission', 'value': 'Automatic'},
#    {'name': 'drive_type', 'value': 'FWD'},
#    {'name': 'fuel_type', 'value': 'Gasoline'},
#    {'name': 'exterior_color', 'value': 'Green'},
#    {'name': 'interior_color', 'value': 'Standard'},
#    {'name': 'trim_level', 'value': 'Standard'},
#    {'name': 'notable_features',
#     'value': ['Air Conditioning', 'AM/FM Radio', 'Power Windows']},
#    {'name': 'safety_features',
#     'value': ['ABS', 'Airbags', 'Child Safety Locks']}],
#   'numberFacetData': [{'name': 'price', 'value': '8900'}],
#   'pathFacetData': [[{'id': None,
#      'name': 'type',
#      'value': 'Type',
#      'type': 'root'},
#     {'id': None, 'name': 'type', 'value': 'Type/Vehicle', 'type': 'type'},
#     {'id': None,
#      'name': 'type',
#      'value': 'Type/Vehicle/Sedan',
#      'type': 'category'}],
#    [{'id': None, 'name': 'brand', 'value': 'Brand', 'type': 'root'},
#     {'id': None, 'name': 'brand', 'value': 'Brand/Nissan', 'type': 'brand'},
#     {'id': None,
#      'name': 'brand',
#      'value': 'Brand/Nissan/Sentra',
#      'type': 'model'}]],
#   'search_data': {'full_text': 'Discover the perfect blend of reliability and efficiency with this 2003 Nissan Sentra. This budget-friendly sedan is ideal for daily commutes and weekend getaways, featuring a comfortable interior and a smooth ride. With its vibrant green exterior, it stands out on the road while providing all the essential features you need for a hassle-free driving experience.',
#    'full_text_boosted': 'Vehicle Sedan Nissan Sentra 2003 I4 2.0L Automatic FWD Gasoline Green Standard Standard Air Conditioning AM/FM Radio Power Windows ABS Airbags Child Safety Locks'},
#   'completion_terms': [{'tag': 'Vehicle'},
#    {'tag': 'Sedan'},
#    {'tag': 'Nissan'},
#    {'tag': 'Sentra'},
#    {'tag': '2003'},
#    {'tag': 'I4'},
#    {'tag': '2.0L'},
#    {'tag': 'Automatic'},
#    {'tag': 'FWD'},
#    {'tag': 'Gasoline'},
#    {'tag': 'Green'},
#    {'tag': 'Standard'},
#    {'tag': 'Standard'},
#    {'tag': 'Air Conditioning'},
#    {'tag': 'AM/FM Radio'},
#    {'tag': 'Power Windows'},
#    {'tag': 'ABS'},
#    {'tag': 'Airbags'},
#    {'tag': 'Child Safety Locks'}],
#   'suggestion_terms': ['Vehicle',
#    'Sedan',
#    'Nissan',
#    'Sentra',
#    '2003',
#    'I4',
#    '2.0L',
#    'Automatic',
#    'FWD',
#    'Gasoline',
#    'Green',
#    'Standard',
#    'Standard',
#    'Air Conditioning',
#    'AM/FM Radio',
#    'Power Windows',
#    'ABS',
#    'Airbags',
#    'Child Safety Locks'],
#   'id': 'e11f7c7f-9105-4d48-aaab-9af2bfc6f89a'},
#  {'termFacetData': [{'name': 'year', 'value': '2003'},
#    {'name': 'engine_type', 'value': 'Diesel'},
#    {'name': 'engine_size', 'value': '6.0L'},
#    {'name': 'transmission', 'value': 'Automatic'},
#    {'name': 'drive_type', 'value': '4WD'},
#    {'name': 'fuel_type', 'value': 'Diesel'},
#    {'name': 'exterior_color', 'value': 'White'},
#    {'name': 'interior_color', 'value': 'Standard'},
#    {'name': 'trim_level', 'value': 'Standard'},
#    {'name': 'notable_features',
#     'value': ['Hydraulic Thumb', 'Bucket with Quick Coupler', 'Cab with AC']},
#    {'name': 'safety_features',
#     'value': ['Stability control', 'Reinforced structure', 'Emergency stop']}],
#   'numberFacetData': [{'name': 'price', 'value': '5200'}],
#   'pathFacetData': [[{'id': None,
#      'name': 'type',
#      'value': 'Type',
#      'type': 'root'},
#     {'id': None, 'name': 'type', 'value': 'Type/Machine', 'type': 'type'},
#     {'id': None,
#      'name': 'type',
#      'value': 'Type/Machine/Hydraulic Excavator',
#      'type': 'category'}],
#    [{'id': None, 'name': 'brand', 'value': 'Brand', 'type': 'root'},
#     {'id': None, 'name': 'brand', 'value': 'Brand/Komatsu', 'type': 'brand'},
#     {'id': None,
#      'name': 'brand',
#      'value': 'Brand/Komatsu/PC300LC-7',
#      'type': 'model'}]],
#   'search_data': {'full_text': 'Discover the rugged reliability of the Komatsu PC300LC-7, a premium hydraulic excavator built for efficiency and performance. With its robust design and powerful capabilities, this machine is perfect for heavy-duty tasks while remaining budget-friendly for your construction needs.',
#    'full_text_boosted': 'Machine Hydraulic Excavator Komatsu PC300LC-7 2003 Diesel 6.0L Automatic 4WD Diesel White Standard Standard Hydraulic Thumb Bucket with Quick Coupler Cab with AC Stability control Reinforced structure Emergency stop'},
#   'completion_terms': [{'tag': 'Machine'},
#    {'tag': 'Hydraulic Excavator'},
#    {'tag': 'Komatsu'},
#    {'tag': 'PC300LC-7'},
#    {'tag': '2003'},
#    {'tag': 'Diesel'},
#    {'tag': '6.0L'},
#    {'tag': 'Automatic'},
#    {'tag': '4WD'},
#    {'tag': 'Diesel'},
#    {'tag': 'White'},
#    {'tag': 'Standard'},
#    {'tag': 'Standard'},
#    {'tag': 'Hydraulic Thumb'},
#    {'tag': 'Bucket with Quick Coupler'},
#    {'tag': 'Cab with AC'},
#    {'tag': 'Stability control'},
#    {'tag': 'Reinforced structure'},
#    {'tag': 'Emergency stop'}],
#   'suggestion_terms': ['Machine',
#    'Hydraulic Excavator',
#    'Komatsu',
#    'PC300LC-7',
#    '2003',
#    'Diesel',
#    '6.0L',
#    'Automatic',
#    '4WD',
#    'Diesel',
#    'White',
#    'Standard',
#    'Standard',
#    'Hydraulic Thumb',
#    'Bucket with Quick Coupler',
#    'Cab with AC',
#    'Stability control',
#    'Reinforced structure',
#    'Emergency stop'],
#   'id': 'c266d009-6e14-41ea-b61d-fe124165f692'},
#  {'termFacetData': [{'name': 'year', 'value': '2005'},
#    {'name': 'engine_type', 'value': 'Diesel'},
#    {'name': 'engine_size', 'value': 'I4 1.8L'},
#    {'name': 'transmission', 'value': 'Automatic'},
#    {'name': 'drive_type', 'value': '4WD'},
#    {'name': 'fuel_type', 'value': 'Diesel'},
#    {'name': 'exterior_color', 'value': 'Black'},
#    {'name': 'interior_color', 'value': 'Standard'},
#    {'name': 'trim_level', 'value': 'Standard'},
#    {'name': 'notable_features',
#     'value': ['Hydraulic thumb', 'Adjustable boom', 'Compact design']},
#    {'name': 'safety_features',
#     'value': ['Stability control', 'Reinforced structure', 'Emergency stop']}],
#   'numberFacetData': [{'name': 'price', 'value': '2600'}],
#   'pathFacetData': [[{'id': None,
#      'name': 'type',
#      'value': 'Type',
#      'type': 'root'},
#     {'id': None, 'name': 'type', 'value': 'Type/Machine', 'type': 'type'},
#     {'id': None,
#      'name': 'type',
#      'value': 'Type/Machine/Mini Excavator',
#      'type': 'category'}],
#    [{'id': None, 'name': 'brand', 'value': 'Brand', 'type': 'root'},
#     {'id': None, 'name': 'brand', 'value': 'Brand/Kubota', 'type': 'brand'},
#     {'id': None,
#      'name': 'brand',
#      'value': 'Brand/Kubota/U35-4HGA',
#      'type': 'model'}]],
#   'search_data': {'full_text': 'Discover the robust and reliable Kubota U35-4HGA, a budget-friendly mini excavator perfect for your construction needs. This 2005 model combines power and efficiency, making it an ideal choice for both professionals and DIY enthusiasts. With its compact design and impressive maneuverability, you can tackle any job with ease. Experience the quality and durability that Kubota is known for.',
#    'full_text_boosted': 'Machine Mini Excavator Kubota U35-4HGA 2005 Diesel I4 1.8L Automatic 4WD Diesel Black Standard Standard Hydraulic thumb Adjustable boom Compact design Stability control Reinforced structure Emergency stop'},
#   'completion_terms': [{'tag': 'Machine'},
#    {'tag': 'Mini Excavator'},
#    {'tag': 'Kubota'},
#    {'tag': 'U35-4HGA'},
#    {'tag': '2005'},
#    {'tag': 'Diesel'},
#    {'tag': 'I4 1.8L'},
#    {'tag': 'Automatic'},
#    {'tag': '4WD'},
#    {'tag': 'Diesel'},
#    {'tag': 'Black'},
#    {'tag': 'Standard'},
#    {'tag': 'Standard'},
#    {'tag': 'Hydraulic thumb'},
#    {'tag': 'Adjustable boom'},
#    {'tag': 'Compact design'},
#    {'tag': 'Stability control'},
#    {'tag': 'Reinforced structure'},
#    {'tag': 'Emergency stop'}],
#   'suggestion_terms': ['Machine',
#    'Mini Excavator',
# ...
#    {'name': 'drive_type', 'value': '4WD'},
#    {'name': 'fuel_type', 'value': 'Diesel'},
#    {'name': 'exterior_color', 'value': 'Blue'},
#    {'name': 'interior_color', 'value': 'Standard'},
#    {'name': 'trim_level', 'value': 'Standard'},
#    {'name': 'notable_features',
#     'value': ['Hydraulic controls',
#      'Adjustable blade',
#      'Comfortable operator seat']},
#    {'name': 'safety_features',
#     'value': ['Stability control',
#      'Reinforced structure',
#      'Rearview camera']}],
#   'numberFacetData': [{'name': 'price', 'value': '5000'}],
#   'pathFacetData': [[{'id': None,
#      'name': 'type',
#      'value': 'Type',
#      'type': 'root'},
#     {'id': None, 'name': 'type', 'value': 'Type/Machine', 'type': 'type'},
#     {'id': None,
#      'name': 'type',
#      'value': 'Type/Machine/Motor Grader',
#      'type': 'category'}],
#    [{'id': None, 'name': 'brand', 'value': 'Brand', 'type': 'root'},
#     {'id': None, 'name': 'brand', 'value': 'Brand/Volvo', 'type': 'brand'},
#     {'id': None,
#      'name': 'brand',
#      'value': 'Brand/Volvo/G960B',
#      'type': 'model'}]],
#   'search_data': {'full_text': "Discover the power and reliability of the 2018 Volvo G960B Motor Grader. This premium machine is designed for precision and efficiency, making it an excellent choice for any construction project. With its robust build and advanced features, it's perfect for those looking for a dependable workhorse that won't break the bank.",
#    'full_text_boosted': 'Machine Motor Grader Volvo G960B 2018 Diesel 6.1L Automatic 4WD Diesel Blue Standard Standard Hydraulic controls Adjustable blade Comfortable operator seat Stability control Reinforced structure Rearview camera'},
#   'completion_terms': [{'tag': 'Machine'},
#    {'tag': 'Motor Grader'},
#    {'tag': 'Volvo'},
#    {'tag': 'G960B'},
#    {'tag': '2018'},
#    {'tag': 'Diesel'},
#    {'tag': '6.1L'},
#    {'tag': 'Automatic'},
#    {'tag': '4WD'},
#    {'tag': 'Diesel'},
#    {'tag': 'Blue'},
#    {'tag': 'Standard'},
#    {'tag': 'Standard'},
#    {'tag': 'Hydraulic controls'},
#    {'tag': 'Adjustable blade'},
#    {'tag': 'Comfortable operator seat'},
#    {'tag': 'Stability control'},
#    {'tag': 'Reinforced structure'},
#    {'tag': 'Rearview camera'}],
#   'suggestion_terms': ['Machine',
#    'Motor Grader',
#    'Volvo',
#    'G960B',
#    '2018',
#    'Diesel',
#    '6.1L',
#    'Automatic',
#    '4WD',
#    'Diesel',
#    'Blue',
#    'Standard',
#    'Standard',
#    'Hydraulic controls',
#    'Adjustable blade',
#    'Comfortable operator seat',
#    'Stability control',
#    'Reinforced structure',
#    'Rearview camera'],
#   'id': 'a8a485e5-139b-4987-9ee1-3fcd318c147b'},
#  {'termFacetData': [{'name': 'year', 'value': '2007'},
#    {'name': 'engine_type', 'value': 'Diesel'},
#    {'name': 'engine_size', 'value': 'I4 2.4L'},
#    {'name': 'transmission', 'value': 'Manual'},
#    {'name': 'drive_type', 'value': '4WD'},
#    {'name': 'fuel_type', 'value': 'Diesel'},
#    {'name': 'exterior_color', 'value': 'Green'},
#    {'name': 'interior_color', 'value': 'Standard'},
#    {'name': 'trim_level', 'value': 'Standard'},
#    {'name': 'notable_features',
#     'value': ['Power Steering', 'Hydraulic Lift', 'Rear PTO']},
#    {'name': 'safety_features',
#     'value': ['Stability Control', 'Reinforced Structure']}],
#   'numberFacetData': [{'name': 'price', 'value': '7700'}],
#   'pathFacetData': [[{'id': None,
#      'name': 'type',
#      'value': 'Type',
#      'type': 'root'},
#     {'id': None, 'name': 'type', 'value': 'Type/Machine', 'type': 'type'},
#     {'id': None,
#      'name': 'type',
#      'value': 'Type/Machine/4WD Tractor',
#      'type': 'category'}],
#    [{'id': None, 'name': 'brand', 'value': 'Brand', 'type': 'root'},
#     {'id': None, 'name': 'brand', 'value': 'Brand/Kubota', 'type': 'brand'},
#     {'id': None,
#      'name': 'brand',
#      'value': 'Brand/Kubota/M6800',
#      'type': 'model'}]],
#   'search_data': {'full_text': 'Experience the power and reliability of the Kubota M6800, a robust 4WD tractor designed for both efficiency and performance. With its durable construction and premium features, this machine is perfect for handling tough tasks while providing exceptional comfort and control. Ideal for those seeking a dependable workhorse at an affordable value.',
#    'full_text_boosted': 'Machine 4WD Tractor Kubota M6800 2007 Diesel I4 2.4L Manual 4WD Diesel Green Standard Standard Power Steering Hydraulic Lift Rear PTO Stability Control Reinforced Structure'},
#   'completion_terms': [{'tag': 'Machine'},
#    {'tag': '4WD Tractor'},
#    {'tag': 'Kubota'},
#    {'tag': 'M6800'},
#    {'tag': '2007'},
#    {'tag': 'Diesel'},
#    {'tag': 'I4 2.4L'},
#    {'tag': 'Manual'},
#    {'tag': '4WD'},
#    {'tag': 'Diesel'},
#    {'tag': 'Green'},
#    {'tag': 'Standard'},
#    {'tag': 'Standard'},
#    {'tag': 'Power Steering'},
#    {'tag': 'Hydraulic Lift'},
#    {'tag': 'Rear PTO'},
#    {'tag': 'Stability Control'},
#    {'tag': 'Reinforced Structure'}],
#   'suggestion_terms': ['Machine',
#    '4WD Tractor',
#    'Kubota',
#    'M6800',
#    '2007',
#    'Diesel',
#    'I4 2.4L',
#    'Manual',
#    '4WD',
#    'Diesel',
#    'Green',
#    'Standard',
#    'Standard',
#    'Power Steering',
#    'Hydraulic Lift',
#    'Rear PTO',
#    'Stability Control',
#    'Reinforced Structure'],
#   'id': '188ee008-906b-4da8-9c4e-8ced4bf78e1a'},
#  {'termFacetData': [{'name': 'year', 'value': '1994'},
#    {'name': 'engine_type', 'value': 'I4'},
#    {'name': 'engine_size', 'value': '1.8L'},
#    {'name': 'transmission', 'value': 'Manual'},
#    {'name': 'drive_type', 'value': 'RWD'},
#    {'name': 'fuel_type', 'value': 'Gasoline'},
#    {'name': 'exterior_color', 'value': 'Black'},
#    {'name': 'interior_color', 'value': 'Standard'},
#    {'name': 'trim_level', 'value': 'Standard'},
#    {'name': 'notable_features',
#     'value': ['Leather seats', 'Bluetooth', 'AM/FM radio']},
#    {'name': 'safety_features',
#     'value': ['ABS', 'Airbags', 'Stability control']}],
#   'numberFacetData': [{'name': 'price', 'value': '4400'}],
#   'pathFacetData': [[{'id': None,
#      'name': 'type',
#      'value': 'Type',
#      'type': 'root'},
#     {'id': None, 'name': 'type', 'value': 'Type/Vehicle', 'type': 'type'},
#     {'id': None,
#      'name': 'type',
#      'value': 'Type/Vehicle/Convertible',
#      'type': 'category'}],
#    [{'id': None, 'name': 'brand', 'value': 'Brand', 'type': 'root'},
#     {'id': None, 'name': 'brand', 'value': 'Brand/MAZDA', 'type': 'brand'},
#     {'id': None,
#      'name': 'brand',
#      'value': 'Brand/MAZDA/MX-5 Miata',
#      'type': 'model'}]],
#   'search_data': {'full_text': 'Experience the joy of driving with this classic 1994 MAZDA MX-5 Miata. This budget-friendly convertible offers a spirited performance with its lightweight design and nimble handling, perfect for those sunny days. Enjoy the thrill of open-air driving in a vehicle that combines style and fun in one compact package.',
#    'full_text_boosted': 'Vehicle Convertible MAZDA MX-5 Miata 1994 I4 1.8L Manual RWD Gasoline Black Standard Standard Leather seats Bluetooth AM/FM radio ABS Airbags Stability control'},
#   'completion_terms': [{'tag': 'Vehicle'},
#    {'tag': 'Convertible'},
#    {'tag': 'MAZDA'},
#    {'tag': 'MX-5 Miata'},
#    {'tag': '1994'},
#    {'tag': 'I4'},
#    {'tag': '1.8L'},
#    {'tag': 'Manual'},
#    {'tag': 'RWD'},
#    {'tag': 'Gasoline'},
#    {'tag': 'Black'},
#    {'tag': 'Standard'},
#    {'tag': 'Standard'},
#    {'tag': 'Leather seats'},
#    {'tag': 'Bluetooth'},
#    {'tag': 'AM/FM radio'},
#    {'tag': 'ABS'},
#    {'tag': 'Airbags'},
#    {'tag': 'Stability control'}],
#   'suggestion_terms': ['Vehicle',
#    'Convertible',
#    'MAZDA',
#    'MX-5 Miata',
#    '1994',
#    'I4',
#    '1.8L',
#    'Manual',
#    'RWD',
#    'Gasoline',
#    'Black',
#    'Standard',
#    'Standard',
#    'Leather seats',
#    'Bluetooth',
#    'AM/FM radio',
#    'ABS',
#    'Airbags',
#    'Stability control'],
#   'id': '06ac699e-4417-4e1b-ae86-0eac7cc09ba9'},
#  {'termFacetData': [{'name': 'year', 'value': '2005'},
#    {'name': 'engine_type', 'value': 'I5'},
#    {'name': 'engine_size', 'value': '2.8L'},
#    {'name': 'transmission', 'value': 'Automatic'},
#    {'name': 'drive_type', 'value': 'RWD'},
#    {'name': 'fuel_type', 'value': 'Gasoline'},
#    {'name': 'exterior_color', 'value': 'Green'},
#    {'name': 'interior_color', 'value': 'Standard'},
#    {'name': 'trim_level', 'value': 'Standard'},
#    {'name': 'notable_features',
#     'value': ['Air Conditioning', 'AM/FM Radio', 'Bed Liner']},
#    {'name': 'safety_features',
#     'value': ['ABS', 'Airbags', 'Stability Control']}],
#   'numberFacetData': [{'name': 'price', 'value': '2700'}],
#   'pathFacetData': [[{'id': None,
#      'name': 'type',
#      'value': 'Type',
#      'type': 'root'},
#     {'id': None, 'name': 'type', 'value': 'Type/Vehicle', 'type': 'type'},
#     {'id': None,
#      'name': 'type',
#      'value': 'Type/Vehicle/Pickup',
#      'type': 'category'}],
#    [{'id': None, 'name': 'brand', 'value': 'Brand', 'type': 'root'},
#     {'id': None, 'name': 'brand', 'value': 'Brand/Chevrolet', 'type': 'brand'},
#     {'id': None,
#      'name': 'brand',
#      'value': 'Brand/Chevrolet/Colorado Regular Cab',
#      'type': 'model'}]],
#   'search_data': {'full_text': "Discover the rugged charm of this 2005 Chevrolet Colorado Regular Cab. With its striking green exterior and reliable performance, this budget-friendly pickup is perfect for both work and play. Enjoy the spacious interior and standard features that make every drive comfortable. Whether you're hauling gear or cruising through town, this Colorado is ready for any adventure.",
#    'full_text_boosted': 'Vehicle Pickup Chevrolet Colorado Regular Cab 2005 I5 2.8L Automatic RWD Gasoline Green Standard Standard Air Conditioning AM/FM Radio Bed Liner ABS Airbags Stability Control'},
#   'completion_terms': [{'tag': 'Vehicle'},
#    {'tag': 'Pickup'},
#    {'tag': 'Chevrolet'},
#    {'tag': 'Colorado Regular Cab'},
#    {'tag': '2005'},
#    {'tag': 'I5'},
#    {'tag': '2.8L'},
#    {'tag': 'Automatic'},
#    {'tag': 'RWD'},
#    {'tag': 'Gasoline'},
#    {'tag': 'Green'},
#    {'tag': 'Standard'},
#    {'tag': 'Standard'},
#    {'tag': 'Air Conditioning'},
#    {'tag': 'AM/FM Radio'},
#    {'tag': 'Bed Liner'},
#    {'tag': 'ABS'},
#    {'tag': 'Airbags'},
#    {'tag': 'Stability Control'}],
#   'suggestion_terms': ['Vehicle',
#    'Pickup',
#    'Chevrolet',
#    'Colorado Regular Cab',
#    '2005',
#    'I5',
#    '2.8L',
#    'Automatic',
#    'RWD',
#    'Gasoline',
#    'Green',
#    'Standard',
#    'Standard',
#    'Air Conditioning',
#    'AM/FM Radio',
#    'Bed Liner',
#    'ABS',
#    'Airbags',
#    'Stability Control'],
#   'id': 'd6607d1a-4203-4a34-9533-04c1cdabd6b7'},
#  {'termFacetData': [{'name': 'year', 'value': '2005'},
#    {'name': 'engine_type', 'value': 'Diesel'},
#    {'name': 'engine_size', 'value': '4.5L'},
#    {'name': 'transmission', 'value': 'Manual'},
#    {'name': 'drive_type', 'value': '4WD'},
#    {'name': 'fuel_type', 'value': 'Diesel'},
#    {'name': 'exterior_color', 'value': 'Blue'},
#    {'name': 'interior_color', 'value': 'Standard'},
#    {'name': 'trim_level', 'value': 'Standard'},
#    {'name': 'notable_features',
#     'value': ['Power steering', 'Hydraulic lift', 'Front loader compatible']},
#    {'name': 'safety_features',
#     'value': ['Stability control',
#      'Reinforced structure',
#      'Rollover protection']}],
#   'numberFacetData': [{'name': 'price', 'value': '5900'}],
#   'pathFacetData': [[{'id': None,
#      'name': 'type',
#      'value': 'Type',
#      'type': 'root'},
#     {'id': None, 'name': 'type', 'value': 'Type/Machine', 'type': 'type'},
#     {'id': None,
#      'name': 'type',
#      'value': 'Type/Machine/4WD Tractor',
#      'type': 'category'}],
#    [{'id': None, 'name': 'brand', 'value': 'Brand', 'type': 'root'},
#     {'id': None, 'name': 'brand', 'value': 'Brand/Case IH', 'type': 'brand'},
#     {'id': None,
#      'name': 'brand',
#      'value': 'Brand/Case IH/MAXXUM 135',
#      'type': 'model'}]],
#   'search_data': {'full_text': 'Experience the power and reliability of the Case IH MAXXUM 135, a robust 4WD tractor designed for both farming and heavy-duty tasks. Its premium build quality and efficient performance make it an excellent choice for those seeking a dependable workhorse. With its striking blue exterior and standard interior, this machine not only performs well but also looks great in any field. Ideal for budget-conscious buyers who demand quality without compromise.',
#    'full_text_boosted': 'Machine 4WD Tractor Case IH MAXXUM 135 2005 Diesel 4.5L Manual 4WD Diesel Blue Standard Standard Power steering Hydraulic lift Front loader compatible Stability control Reinforced structure Rollover protection'},
#   'completion_terms': [{'tag': 'Machine'},
#    {'tag': '4WD Tractor'},
#    {'tag': 'Case IH'},
#    {'tag': 'MAXXUM 135'},
#    {'tag': '2005'},
#    {'tag': 'Diesel'},
#    {'tag': '4.5L'},
#    {'tag': 'Manual'},
#    {'tag': '4WD'},
#    {'tag': 'Diesel'},
#    {'tag': 'Blue'},
#    {'tag': 'Standard'},
#    {'tag': 'Standard'},
#    {'tag': 'Power steering'},
#    {'tag': 'Hydraulic lift'},
#    {'tag': 'Front loader compatible'},
#    {'tag': 'Stability control'},
#    {'tag': 'Reinforced structure'},
#    {'tag': 'Rollover protection'}],
#   'suggestion_terms': ['Machine',
#    '4WD Tractor',
#    'Case IH',
#    'MAXXUM 135',
#    '2005',
#    'Diesel',
#    '4.5L',
#    'Manual',
#    '4WD',
#    'Diesel',
#    'Blue',
#    'Standard',
#    'Standard',
#    'Power steering',
#    'Hydraulic lift',
#    'Front loader compatible',
#    'Stability control',
#    'Reinforced structure',
#    'Rollover protection'],
#   'id': '8dbd6276-cdcb-4ca9-ae2f-2ef93ce19eca'},
#  {'termFacetData': [{'name': 'year', 'value': '2001'},
#    {'name': 'engine_type', 'value': 'V8'},
#    {'name': 'engine_size', 'value': '5.7L'},
#    {'name': 'transmission', 'value': 'Automatic'},
#    {'name': 'drive_type', 'value': 'RWD'},
#    {'name': 'fuel_type', 'value': 'Gasoline'},
#    {'name': 'exterior_color', 'value': 'Black'},
#    {'name': 'interior_color', 'value': 'Standard'},
#    {'name': 'trim_level', 'value': 'Standard'},
#    {'name': 'notable_features',
#     'value': ['Spacious interior', 'Air conditioning', 'AM/FM radio']},
#    {'name': 'safety_features',
#     'value': ['ABS', 'Airbags', 'Stability control']}],
#   'numberFacetData': [{'name': 'price', 'value': '2500'}],
#   'pathFacetData': [[{'id': None,
#      'name': 'type',
#      'value': 'Type',
#      'type': 'root'},
#     {'id': None, 'name': 'type', 'value': 'Type/Vehicle', 'type': 'type'},
#     {'id': None,
#      'name': 'type',
#      'value': 'Type/Vehicle/Van/Minivan',
#      'type': 'category'}],
#    [{'id': None, 'name': 'brand', 'value': 'Brand', 'type': 'root'},
#     {'id': None, 'name': 'brand', 'value': 'Brand/GMC', 'type': 'brand'},
#     {'id': None,
#      'name': 'brand',
#      'value': 'Brand/GMC/Savana 1500 Passenger',
#      'type': 'model'}]],
#   'search_data': {'full_text': "Discover the spacious and versatile GMC Savana 1500 Passenger, perfect for family outings or group travels. This reliable van combines comfort with functionality, making it an excellent choice for those seeking a budget-friendly vehicle that doesn’t compromise on quality. With its robust design and ample seating, you'll enjoy every journey.",
#    'full_text_boosted': 'Vehicle Van/Minivan GMC Savana 1500 Passenger 2001 V8 5.7L Automatic RWD Gasoline Black Standard Standard Spacious interior Air conditioning AM/FM radio ABS Airbags Stability control'},
#   'completion_terms': [{'tag': 'Vehicle'},
#    {'tag': 'Van/Minivan'},
#    {'tag': 'GMC'},
#    {'tag': 'Savana 1500 Passenger'},
#    {'tag': '2001'},
#    {'tag': 'V8'},
#    {'tag': '5.7L'},
#    {'tag': 'Automatic'},
#    {'tag': 'RWD'},
#    {'tag': 'Gasoline'},
#    {'tag': 'Black'},
#    {'tag': 'Standard'},
#    {'tag': 'Standard'},
#    {'tag': 'Spacious interior'},
#    {'tag': 'Air conditioning'},
#    {'tag': 'AM/FM radio'},
#    {'tag': 'ABS'},
#    {'tag': 'Airbags'},
#    {'tag': 'Stability control'}],
#   'suggestion_terms': ['Vehicle',
#    'Van/Minivan',
#    'GMC',
#    'Savana 1500 Passenger',
#    '2001',
#    'V8',
#    '5.7L',
#    'Automatic',
#    'RWD',
#    'Gasoline',
#    'Black',
#    'Standard',
#    'Standard',
#    'Spacious interior',
#    'Air conditioning',
#    'AM/FM radio',
#    'ABS',
#    'Airbags',
#    'Stability control'],
#   'id': 'e9bb14ca-f63b-403b-aa24-47f297841097'},
#  ...]

# %% [markdown]
# # 3. Load Data

# %%
with open("mapping/settings.json", "r") as file:
    settings = json.load(file)["settings"]

with open("mapping/mappings.json", "r") as file:
    mappings = json.load(file)["mappings"]

# %%
resp = es.reindex(
    index=idx,
    documents=documents,
    mappings=mappings,
    settings=settings,
    # pipeline="ingest",
)
print(
    f'Index with {len(resp["items"])} documents created '
    f'in {resp["took"]} milliseconds.'
)
# Out:
# Index 'vehicle' created successfully.
# 5000 documents inserted into 'vehicle'
# Index with 5000 documents created in 239017 milliseconds.

# %%
resp.body
# Out:
# {'errors': False,
#  'took': 239017,
#  'items': [{'index': {'_index': 'vehicle',
#     '_id': 'SRvIvZMBPskx_3jzO4fF',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 0,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': 'ShvIvZMBPskx_3jzO4fF',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 1,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': 'SxvIvZMBPskx_3jzO4fF',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 2,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': 'TBvIvZMBPskx_3jzO4fF',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 3,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': 'TRvIvZMBPskx_3jzO4fF',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 4,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': 'ThvIvZMBPskx_3jzO4fF',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 5,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': 'TxvIvZMBPskx_3jzO4fF',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 6,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': 'UBvIvZMBPskx_3jzO4fF',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 7,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': 'URvIvZMBPskx_3jzO4fF',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 8,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': 'UhvIvZMBPskx_3jzO4fF',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 9,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': 'UxvIvZMBPskx_3jzO4fF',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 10,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': 'VBvIvZMBPskx_3jzO4fF',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 11,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': 'VRvIvZMBPskx_3jzO4fF',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 12,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': 'VhvIvZMBPskx_3jzO4fF',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 13,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': 'VxvIvZMBPskx_3jzO4fF',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 14,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': 'WBvIvZMBPskx_3jzO4fF',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 15,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': 'WRvIvZMBPskx_3jzO4fF',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 16,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': 'WhvIvZMBPskx_3jzO4fF',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 17,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': 'WxvIvZMBPskx_3jzO4fF',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 18,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': 'XBvIvZMBPskx_3jzO4fF',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 19,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': 'XRvIvZMBPskx_3jzO4fF',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 20,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': 'XhvIvZMBPskx_3jzO4fF',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 21,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': 'XxvIvZMBPskx_3jzO4fF',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 22,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': 'YBvIvZMBPskx_3jzO4fF',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 23,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': 'YRvIvZMBPskx_3jzO4fF',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 24,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': 'YhvIvZMBPskx_3jzO4fF',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 25,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': 'YxvIvZMBPskx_3jzO4fF',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 26,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': 'ZBvIvZMBPskx_3jzO4fF',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 27,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': 'ZRvIvZMBPskx_3jzO4fF',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 28,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': 'ZhvIvZMBPskx_3jzO4fF',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 29,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': 'ZxvIvZMBPskx_3jzO4fF',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 30,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': 'aBvIvZMBPskx_3jzO4fF',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 31,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': 'aRvIvZMBPskx_3jzO4fF',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 32,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': 'ahvIvZMBPskx_3jzO4fF',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 33,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': 'axvIvZMBPskx_3jzO4fF',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 34,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': 'bBvIvZMBPskx_3jzO4fF',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 35,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': 'bRvIvZMBPskx_3jzO4fF',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 36,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': 'bhvIvZMBPskx_3jzO4fF',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 37,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': 'bxvIvZMBPskx_3jzO4fF',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 38,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': 'cBvIvZMBPskx_3jzO4fF',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 39,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': 'cRvIvZMBPskx_3jzO4fF',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 40,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': 'chvIvZMBPskx_3jzO4fF',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 41,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': 'cxvIvZMBPskx_3jzO4fF',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 42,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': 'dBvIvZMBPskx_3jzO4fF',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 43,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': 'dRvIvZMBPskx_3jzO4fG',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 44,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': 'dhvIvZMBPskx_3jzO4fG',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 45,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': 'dxvIvZMBPskx_3jzO4fG',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 46,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': 'eBvIvZMBPskx_3jzO4fG',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 47,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': 'eRvIvZMBPskx_3jzO4fG',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 48,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': 'ehvIvZMBPskx_3jzO4fG',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 49,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': 'exvIvZMBPskx_3jzO4fG',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 50,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': 'fBvIvZMBPskx_3jzO4fG',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 51,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': 'fRvIvZMBPskx_3jzO4fG',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 52,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': 'fhvIvZMBPskx_3jzO4fG',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 53,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': 'fxvIvZMBPskx_3jzO4fG',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 54,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': 'gBvIvZMBPskx_3jzO4fG',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 55,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': 'gRvIvZMBPskx_3jzO4fG',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 56,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': 'ghvIvZMBPskx_3jzO4fG',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 57,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': 'gxvIvZMBPskx_3jzO4fG',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 58,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': 'hBvIvZMBPskx_3jzO4fG',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 59,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': 'hRvIvZMBPskx_3jzO4fG',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 60,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': 'hhvIvZMBPskx_3jzO4fG',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 61,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': 'hxvIvZMBPskx_3jzO4fG',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 62,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': 'iBvIvZMBPskx_3jzO4fG',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 63,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': 'iRvIvZMBPskx_3jzO4fG',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 64,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': 'ihvIvZMBPskx_3jzO4fG',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 65,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': 'ixvIvZMBPskx_3jzO4fG',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 66,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': 'jBvIvZMBPskx_3jzO4fG',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 67,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': 'jRvIvZMBPskx_3jzO4fG',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 68,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': 'jhvIvZMBPskx_3jzO4fG',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 69,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': 'jxvIvZMBPskx_3jzO4fG',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 70,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': 'kBvIvZMBPskx_3jzO4fG',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 71,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': 'kRvIvZMBPskx_3jzO4fG',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 72,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': 'khvIvZMBPskx_3jzO4fG',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 73,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': 'kxvIvZMBPskx_3jzO4fG',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 74,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': 'lBvIvZMBPskx_3jzO4fG',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 75,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': 'lRvIvZMBPskx_3jzO4fG',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 76,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': 'lhvIvZMBPskx_3jzO4fG',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 77,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': 'lxvIvZMBPskx_3jzO4fG',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 78,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': 'mBvIvZMBPskx_3jzO4fG',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 79,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': 'mRvIvZMBPskx_3jzO4fG',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 80,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': 'mhvIvZMBPskx_3jzO4fG',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 81,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': 'mxvIvZMBPskx_3jzO4fG',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 82,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': 'nBvIvZMBPskx_3jzO4fG',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 83,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': 'nRvIvZMBPskx_3jzO4fG',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 84,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': 'nhvIvZMBPskx_3jzO4fG',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 85,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': 'nxvIvZMBPskx_3jzO4fG',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 86,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': 'oBvIvZMBPskx_3jzO4fG',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 87,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': 'oRvIvZMBPskx_3jzO4fG',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 88,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': 'ohvIvZMBPskx_3jzO4fG',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 89,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': 'oxvIvZMBPskx_3jzO4fG',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 90,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': 'pBvIvZMBPskx_3jzO4fG',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 91,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': 'pRvIvZMBPskx_3jzO4fG',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 92,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': 'phvIvZMBPskx_3jzO4fG',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 93,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': 'pxvIvZMBPskx_3jzO4fG',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 94,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': 'qBvIvZMBPskx_3jzO4fG',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 95,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': 'qRvIvZMBPskx_3jzO4fG',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 96,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': 'qhvIvZMBPskx_3jzO4fG',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 97,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': 'qxvIvZMBPskx_3jzO4fG',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 98,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': 'rBvIvZMBPskx_3jzO4fG',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 99,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': 'rRvIvZMBPskx_3jzO4fG',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 100,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': 'rhvIvZMBPskx_3jzO4fG',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 101,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': 'rxvIvZMBPskx_3jzO4fG',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 102,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': 'sBvIvZMBPskx_3jzO4fG',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 103,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': 'sRvIvZMBPskx_3jzO4fG',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 104,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': 'shvIvZMBPskx_3jzO4fG',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 105,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': 'sxvIvZMBPskx_3jzO4fG',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 106,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': 'tBvIvZMBPskx_3jzO4fG',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 107,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': 'tRvIvZMBPskx_3jzO4fG',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 108,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': 'thvIvZMBPskx_3jzO4fG',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 109,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': 'txvIvZMBPskx_3jzO4fG',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 110,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': 'uBvIvZMBPskx_3jzO4fG',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 111,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': 'uRvIvZMBPskx_3jzO4fG',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 112,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': 'uhvIvZMBPskx_3jzO4fG',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 113,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': 'uxvIvZMBPskx_3jzO4fG',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 114,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': 'vBvIvZMBPskx_3jzO4fG',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 115,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': 'vRvIvZMBPskx_3jzO4fG',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 116,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': 'vhvIvZMBPskx_3jzO4fG',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 117,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': 'vxvIvZMBPskx_3jzO4fG',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 118,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': 'wBvIvZMBPskx_3jzO4fG',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 119,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': 'wRvIvZMBPskx_3jzO4fG',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 120,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': 'whvIvZMBPskx_3jzO4fG',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 121,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': 'wxvIvZMBPskx_3jzO4fG',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 122,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': 'xBvIvZMBPskx_3jzO4fG',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 123,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': 'xRvIvZMBPskx_3jzO4fG',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 124,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': 'xhvIvZMBPskx_3jzO4fG',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 125,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': 'xxvIvZMBPskx_3jzO4fG',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 126,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': 'yBvIvZMBPskx_3jzO4fG',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 127,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': 'yRvIvZMBPskx_3jzO4fG',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 128,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': 'yhvIvZMBPskx_3jzO4fG',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 129,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': 'yxvIvZMBPskx_3jzO4fG',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 130,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': 'zBvIvZMBPskx_3jzO4fG',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 131,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': 'zRvIvZMBPskx_3jzO4fG',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 132,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': 'zhvIvZMBPskx_3jzO4fG',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 133,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': 'zxvIvZMBPskx_3jzO4fG',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 134,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': '0BvIvZMBPskx_3jzO4fG',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 135,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': '0RvIvZMBPskx_3jzO4fG',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 136,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': '0hvIvZMBPskx_3jzO4fG',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 137,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': '0xvIvZMBPskx_3jzO4fG',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 138,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': '1BvIvZMBPskx_3jzO4fG',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 139,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': '1RvIvZMBPskx_3jzO4fG',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 140,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': '1hvIvZMBPskx_3jzO4fG',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 141,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': '1xvIvZMBPskx_3jzO4fG',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 142,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': '2BvIvZMBPskx_3jzO4fG',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 143,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': '2RvIvZMBPskx_3jzO4fG',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 144,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': '2hvIvZMBPskx_3jzO4fG',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 145,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': '2xvIvZMBPskx_3jzO4fG',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 146,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': '3BvIvZMBPskx_3jzO4fG',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 147,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': '3RvIvZMBPskx_3jzO4fG',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 148,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': '3hvIvZMBPskx_3jzO4fG',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 149,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': '3xvIvZMBPskx_3jzO4fG',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 150,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': '4BvIvZMBPskx_3jzO4fG',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 151,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': '4RvIvZMBPskx_3jzO4fG',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 152,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': '4hvIvZMBPskx_3jzO4fG',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 153,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': '4xvIvZMBPskx_3jzO4fG',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 154,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': '5BvIvZMBPskx_3jzO4fG',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 155,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': '5RvIvZMBPskx_3jzO4fG',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 156,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': '5hvIvZMBPskx_3jzO4fG',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 157,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': '5xvIvZMBPskx_3jzO4fG',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 158,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': '6BvIvZMBPskx_3jzO4fG',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 159,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': '6RvIvZMBPskx_3jzO4fG',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 160,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': '6hvIvZMBPskx_3jzO4fG',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 161,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': '6xvIvZMBPskx_3jzO4fG',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 162,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': '7BvIvZMBPskx_3jzO4fG',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 163,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': '7RvIvZMBPskx_3jzO4fG',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 164,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': '7hvIvZMBPskx_3jzO4fG',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 165,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': '7xvIvZMBPskx_3jzO4fG',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 166,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': '8BvIvZMBPskx_3jzO4fG',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 167,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': '8RvIvZMBPskx_3jzO4fG',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 168,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': '8hvIvZMBPskx_3jzO4fG',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 169,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': '8xvIvZMBPskx_3jzO4fG',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 170,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': '9BvIvZMBPskx_3jzO4fG',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 171,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': '9RvIvZMBPskx_3jzO4fG',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 172,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': '9hvIvZMBPskx_3jzO4fG',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 173,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': '9xvIvZMBPskx_3jzO4fG',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 174,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': '-BvIvZMBPskx_3jzO4fG',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 175,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': '-RvIvZMBPskx_3jzO4fG',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 176,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': '-hvIvZMBPskx_3jzO4fG',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 177,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': '-xvIvZMBPskx_3jzO4fG',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 178,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': '_BvIvZMBPskx_3jzO4fG',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 179,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': '_RvIvZMBPskx_3jzO4fG',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 180,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': '_hvIvZMBPskx_3jzO4fG',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 181,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': '_xvIvZMBPskx_3jzO4fG',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 182,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': 'ABvIvZMBPskx_3jzO4jG',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 183,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': 'ARvIvZMBPskx_3jzO4jG',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 184,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': 'AhvIvZMBPskx_3jzO4jG',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 185,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': 'AxvIvZMBPskx_3jzO4jG',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 186,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': 'BBvIvZMBPskx_3jzO4jG',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 187,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': 'BRvIvZMBPskx_3jzO4jG',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 188,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': 'BhvIvZMBPskx_3jzO4jG',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 189,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': 'BxvIvZMBPskx_3jzO4jG',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 190,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': 'CBvIvZMBPskx_3jzO4jG',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 191,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': 'CRvIvZMBPskx_3jzO4jG',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 192,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': 'ChvIvZMBPskx_3jzO4jG',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 193,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': 'CxvIvZMBPskx_3jzO4jG',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 194,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': 'DBvIvZMBPskx_3jzO4jG',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 195,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': 'DRvIvZMBPskx_3jzO4jG',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 196,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': 'DhvIvZMBPskx_3jzO4jG',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 197,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': 'DxvIvZMBPskx_3jzO4jG',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 198,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': 'EBvIvZMBPskx_3jzO4jG',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 199,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': 'ERvIvZMBPskx_3jzO4jG',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 200,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': 'EhvIvZMBPskx_3jzO4jG',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 201,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': 'ExvIvZMBPskx_3jzO4jG',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 202,
# ...
#     '_seq_no': 932,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': '7hvIvZMBPskx_3jzO4rJ',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 933,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': '7xvIvZMBPskx_3jzO4rJ',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 934,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': '8BvIvZMBPskx_3jzO4rJ',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 935,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': '8RvIvZMBPskx_3jzO4rJ',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 936,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': '8hvIvZMBPskx_3jzO4rJ',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 937,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': '8xvIvZMBPskx_3jzO4rJ',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 938,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': '9BvIvZMBPskx_3jzO4rJ',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 939,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': '9RvIvZMBPskx_3jzO4rJ',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 940,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': '9hvIvZMBPskx_3jzO4rJ',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 941,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': '9xvIvZMBPskx_3jzO4rJ',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 942,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': '-BvIvZMBPskx_3jzO4rJ',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 943,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': '-RvIvZMBPskx_3jzO4rJ',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 944,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': '-hvIvZMBPskx_3jzO4rJ',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 945,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': '-xvIvZMBPskx_3jzO4rJ',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 946,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': '_BvIvZMBPskx_3jzO4rJ',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 947,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': '_RvIvZMBPskx_3jzO4rJ',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 948,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': '_hvIvZMBPskx_3jzO4rJ',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 949,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': '_xvIvZMBPskx_3jzO4rJ',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 950,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': 'ABvIvZMBPskx_3jzO4vJ',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 951,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': 'ARvIvZMBPskx_3jzO4vJ',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 952,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': 'AhvIvZMBPskx_3jzO4vJ',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 953,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': 'AxvIvZMBPskx_3jzO4vJ',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 954,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': 'BBvIvZMBPskx_3jzO4vJ',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 955,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': 'BRvIvZMBPskx_3jzO4vJ',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 956,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': 'BhvIvZMBPskx_3jzO4vJ',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 957,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': 'BxvIvZMBPskx_3jzO4vJ',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 958,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': 'CBvIvZMBPskx_3jzO4vJ',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 959,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': 'CRvIvZMBPskx_3jzO4vJ',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 960,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': 'ChvIvZMBPskx_3jzO4vJ',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 961,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': 'CxvIvZMBPskx_3jzO4vJ',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 962,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': 'DBvIvZMBPskx_3jzO4vJ',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 963,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': 'DRvIvZMBPskx_3jzO4vJ',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 964,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': 'DhvIvZMBPskx_3jzO4vJ',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 965,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': 'DxvIvZMBPskx_3jzO4vJ',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 966,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': 'EBvIvZMBPskx_3jzO4vJ',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 967,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': 'ERvIvZMBPskx_3jzO4vJ',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 968,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': 'EhvIvZMBPskx_3jzO4vJ',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 969,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': 'ExvIvZMBPskx_3jzO4vJ',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 970,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': 'FBvIvZMBPskx_3jzO4vJ',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 971,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': 'FRvIvZMBPskx_3jzO4vJ',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 972,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': 'FhvIvZMBPskx_3jzO4vJ',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 973,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': 'FxvIvZMBPskx_3jzO4vJ',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 974,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': 'GBvIvZMBPskx_3jzO4vJ',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 975,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': 'GRvIvZMBPskx_3jzO4vJ',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 976,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': 'GhvIvZMBPskx_3jzO4vJ',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 977,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': 'GxvIvZMBPskx_3jzO4vJ',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 978,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': 'HBvIvZMBPskx_3jzO4vJ',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 979,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': 'HRvIvZMBPskx_3jzO4vJ',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 980,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': 'HhvIvZMBPskx_3jzO4vJ',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 981,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': 'HxvIvZMBPskx_3jzO4vJ',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 982,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': 'IBvIvZMBPskx_3jzO4vJ',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 983,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': 'IRvIvZMBPskx_3jzO4vJ',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 984,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': 'IhvIvZMBPskx_3jzO4vJ',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 985,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': 'IxvIvZMBPskx_3jzO4vJ',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 986,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': 'JBvIvZMBPskx_3jzO4vJ',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 987,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': 'JRvIvZMBPskx_3jzO4vJ',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 988,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': 'JhvIvZMBPskx_3jzO4vJ',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 989,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': 'JxvIvZMBPskx_3jzO4vJ',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 990,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': 'KBvIvZMBPskx_3jzO4vJ',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 991,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': 'KRvIvZMBPskx_3jzO4vJ',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 992,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': 'KhvIvZMBPskx_3jzO4vJ',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 993,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': 'KxvIvZMBPskx_3jzO4vJ',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 994,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': 'LBvIvZMBPskx_3jzO4vJ',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 995,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': 'LRvIvZMBPskx_3jzO4vJ',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 996,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': 'LhvIvZMBPskx_3jzO4vJ',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 997,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': 'LxvIvZMBPskx_3jzO4vJ',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 998,
#     '_primary_term': 1,
#     'status': 201}},
#   {'index': {'_index': 'vehicle',
#     '_id': 'MBvIvZMBPskx_3jzO4vJ',
#     '_version': 1,
#     'result': 'created',
#     '_shards': {'total': 2, 'successful': 1, 'failed': 0},
#     '_seq_no': 999,
#     '_primary_term': 1,
#     'status': 201}},
#   ...]}

# %%
resp = es.search(index="vehicle", size=1)
# Out:
# Search results from 'vehicle' retrieved successfully in 60 ms.

# %%
resp.body
# Out:
# {'took': 60,
#  'timed_out': False,
#  '_shards': {'total': 1, 'successful': 1, 'skipped': 0, 'failed': 0},
#  'hits': {'total': {'value': 3258, 'relation': 'eq'},
#   'max_score': 1.0,
#   'hits': [{'_index': 'vehicle',
#     '_id': 'SRvIvZMBPskx_3jzO4fF',
#     '_score': 1.0,
#     '_source': {'termFacetData': [{'name': 'year', 'value': '2008'},
#       {'name': 'engine_type', 'value': 'I4'},
#       {'name': 'engine_size', 'value': '1.8L'},
#       {'name': 'transmission', 'value': 'Manual'},
#       {'name': 'drive_type', 'value': 'RWD'},
#       {'name': 'fuel_type', 'value': 'Gasoline'},
#       {'name': 'exterior_color', 'value': 'Red'},
#       {'name': 'interior_color', 'value': 'Standard'},
#       {'name': 'trim_level', 'value': 'Standard'},
#       {'name': 'notable_features',
#        'value': ['Leather seats', 'Navigation', 'Bluetooth']},
#       {'name': 'safety_features',
#        'value': ['ABS', 'Airbags', 'Stability control']}],
#      'numberFacetData': [{'name': 'price', 'value': '5700'}],
#      'pathFacetData': [[{'id': None,
#         'name': 'type',
#         'value': 'Type',
#         'type': 'root'},
#        {'id': None, 'name': 'type', 'value': 'Type/Vehicle', 'type': 'type'},
#        {'id': None,
#         'name': 'type',
#         'value': 'Type/Vehicle/Coupe',
#         'type': 'category'}],
#       [{'id': None, 'name': 'brand', 'value': 'Brand', 'type': 'root'},
#        {'id': None, 'name': 'brand', 'value': 'Brand/Lotus', 'type': 'brand'},
#        {'id': None,
#         'name': 'brand',
#         'value': 'Brand/Lotus/Exige S',
#         'type': 'model'}]],
#      'search_data': {'full_text': 'Experience the thrill of driving with this 2008 Lotus Exige S, a budget-friendly sports coupe that combines lightweight design with exhilarating performance. With its striking red exterior and agile handling, this vehicle promises an unforgettable ride. Perfect for enthusiasts seeking a unique driving experience without breaking the bank.',
#       'full_text_boosted': 'Vehicle Coupe Lotus Exige S 2008 I4 1.8L Manual RWD Gasoline Red Standard Standard Leather seats Navigation Bluetooth ABS Airbags Stability control'},
#      'completion_terms': [{'tag': 'Vehicle'},
#       {'tag': 'Coupe'},
#       {'tag': 'Lotus'},
#       {'tag': 'Exige S'},
#       {'tag': '2008'},
#       {'tag': 'I4'},
#       {'tag': '1.8L'},
#       {'tag': 'Manual'},
#       {'tag': 'RWD'},
#       {'tag': 'Gasoline'},
#       {'tag': 'Red'},
#       {'tag': 'Standard'},
#       {'tag': 'Standard'},
#       {'tag': 'Leather seats'},
#       {'tag': 'Navigation'},
#       {'tag': 'Bluetooth'},
#       {'tag': 'ABS'},
#       {'tag': 'Airbags'},
#       {'tag': 'Stability control'}],
#      'suggestion_terms': ['Vehicle',
#       'Coupe',
#       'Lotus',
#       'Exige S',
#       '2008',
#       'I4',
#       '1.8L',
#       'Manual',
#       'RWD',
#       'Gasoline',
#       'Red',
#       'Standard',
#       'Standard',
#       'Leather seats',
#       'Navigation',
#       'Bluetooth',
#       'ABS',
#       'Airbags',
#       'Stability control'],
#      'id': 'e880f9d6-7937-4696-8bb5-0cd0e8517ec1'}}]}}
